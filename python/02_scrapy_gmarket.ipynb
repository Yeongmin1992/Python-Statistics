# %% [markdown]
# ### scrapy
# - 파이썬 언어를 이용한 웹 데이터 수집 프레임 워크
#     - 프레임워크와 라이브러리 또는 패키지의 창
#     - 프레임워크는 특정 목적을 가진 기능의 코드가 미리 설정 되어서 빈칸채우기 식으로 코드를 작성
#     - 패키지는 다른 사람이 작성해 놓은 코들를 가져다가 사용하는 방법
# - scrapy
#     - pit install scrapy
# - tree
#     - sudo apt install tree

# %% [markdown]
# #### index
# - xpath : css-selector 역할을 해주는 문법
# - 스크래피의 구조
# - gmarket 베스트 상품 데이터 크롤링

# %%
import scrapy
import requests
from scrapy.http import TextResponse # xpath 연습

# %% [markdown]
# #### 1. xpath 사용법
# - 네이버, 다음 실시간 검색어 데이터
# - 네이버 검색어 xpath
#
# ```
# //*[@id="NM_RTK_ROLLING_WRAP"]/div/a/span
# ```
#
# - `//` : 가장 상위 엘리먼트
# - '*' : 조건에 맞는 하위 엘리먼트를 모두 살펴봄, css selector의 "div. txt"와 같은 기능
# - '[@id="NM_RTK_ROLLING_WRAP"]' : 조건 : id가 NM_RTK_ROLLING_WRAP 인 엘리먼트
# - '/' : 바로 아래 엘리먼트를 살펴봄, "div > .txt"
# - `div[1]` : div태그에서 1 번째 엘리먼트를 선택
# - `-`: 현재 엘리먼트를 선택
# - `not` : not(조건)

# %%
# 웹페이지에 연결
req = requests.get("https://www.naver.com/")

# response 객체 생성, beautiful soup으로 parsing 하던 것을 scrapy의 response로 parsing 한다고 생각하면 됨.
response = TextResponse(req.url, body=req.text, encoding="utf-8")

# %%
# 네이버 키워드 순위 데이터 가져오기
# xpath: xpath selector
# data : xpath selector로 선택된 엘리먼트

response.xpath('//*[@id="NM_RTK_ROLLING_WRAP"]/div/div/a/span[2]')
# Out:
# []

# %%
# text를 data로 설정
response.xpath('//*[@id="NM_RTK_ROLLING_WRAP"]/div/a/span/text()')
# Out:
# []

# %%
# response 객체에서 data 변수만 가져옴
response.xpath('//*[@id="NM_RTK_ROLLING_WRAP"]/div/a/span/text()').extract()

# %%
//*[@id="NM_RTK_ROLLING_WRAP"]/div/div

# %% [markdown]
# #### 2. Scrapy Project
# - scrapy 프로젝트 생성
# - scrapy 구조
# - gmarket 베스트 상품 링크 수집, 링크 안에 있는 상세 정보 수집

# %%
# 프로젝트 생성

# %%
# !scrapy startproject crawler
# Out:
# New Scrapy project 'crawler', using template directory '/home/ubuntu/.pyenv/versions/3.6.9/envs/python3/lib/python3.6/site-packages/scrapy/templates/project', created in:
#     /home/ubuntu/python3/notebook/crawler
#
# You can start your first spider with:
#     cd crawler
#     scrapy genspider example example.com

# %%
# !ls
# Out:
#  01_mysql_with_python.ipynb	 Package.ipynb
#  02_SQLAlchemy.ipynb		 __pycache__
#  03_pymongo.ipynb		 calc
#  04_slack.ipynb			 crawler
#  05_requests_1.ipynb		 mypack
#  06_requests_2.ipynb		 naver_main.png
#  07_selenium_server.ipynb	 summary_database.ipynb
# '08_iterator, generator.ipynb'	 zigbang.py
#  09_scrapy_gmarket.ipynb

# %%
# !tree crawler
# Out:
# crawler
# ├── crawler
# │   ├── __init__.py
# │   ├── __pycache__
# │   ├── items.py
# │   ├── middlewares.py
# │   ├── pipelines.py
# │   ├── settings.py
# │   └── spiders
# │       ├── __init__.py
# │       └── __pycache__
# └── scrapy.cfg
#
# 4 directories, 7 files

# %% [markdown]
# #### scrapy의 구조
# - spiders
#     - 어떤 웹서비스를 어떻게 크롤링 할 것 인지에 대한 코드를 작성(.py 파일로 작성)
# - items.py
#     - 모델에 해당하는 코드, 저장하는 제이터의 자료구조를 설정
# - pipelines.py
#     - 스크래핑 한 결과물을 item 형태로 구성하고 처리하는 방법에 대한 코드
# - settings.py
#     - 스크래핑 할 때의 환경설정값을 지정
#     - robot.txt : 따를지 안따를지

# %% [markdown]
# #### gmarket 베스트 셀러 상품 수집
# - 상품명, 상세페이지 URL, 원가, 판매가, 할인률
# - xpath 확인
# - items.py
# - spider.py
# - 크롤러 실행

# %% [markdown]
# ###$ 1. xpath 확인

# %%
req = requests.get("http://corners.gmarket.co.kr/Bestsellers")
response = TextResponse(req.url, body=req.text, encoding="utf-8")

# %%
items = response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li')
len(items)
# Out:
# 200

# %%
links = response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li/div[1]/a')
len(links)
# Out:
# 200

# %%
links[0]
# Out:
# <Selector xpath='//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li/div[1]/a' data='<a href="http://item.gmarket.co.kr/It...'>

# %%
links = response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li/div[1]/a/@href')
len(links)
# Out:
# 200

# %%
links[0]
# Out:
# <Selector xpath='//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li/div[1]/a/@href' data='http://item.gmarket.co.kr/Item?goodsc...'>

# %%
links = response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li/div[1]/a/@href').extract()

# %%
links[0]
# Out:
# 'http://item.gmarket.co.kr/Item?goodscode=1620413379&ver=637292869981332930'

# %%
req = requests.get(links[0])
response = TextResponse(req.url, body=req.text, encoding="utf-8")
title = response.xpath('//*[@id="itemcase_basic"]/h1/text()')[0].extract() 
s_price = response.xpath('//*[@id="itemcase_basic"]/p/span/strong/text()')[0].extract()
o_price = response.xpath('//*[@id="itemcase_basic"]/p/span/span/text()')[0].extract()
# discount_rate
title, s_price, o_price
# Out:
# ('키위 제스프리 골드 키위 특대과 30과 ', '27,900', '43,350')

# %%
req = requests.get(links[0])
response = TextResponse(req.url, body=req.text, encoding="utf-8")
title = response.xpath('//*[@id="itemcase_basic"]/h1/text()')[0].extract() 
s_price = response.xpath('//*[@id="itemcase_basic"]/p/span/strong/text()')[0].extract().replace(",", "")
o_price = response.xpath('//*[@id="itemcase_basic"]/p/span/span/text()')[0].extract().replace(",", "")
discount_rate = str(round((1 - int(s_price) / int(o_price))*100, 2)) + "%"
title, s_price, o_price, discount_rate
# Out:
# ('키위 제스프리 골드 키위 특대과 30과 ', '27900', '43350', '35.64%')

# %% [markdown]
# #### 2. items.py 작성

# %%
! cat crawler/crawler/items.py
# Out:
# # Define here the models for your scraped items
# #
# # See documentation in:
# # https://docs.scrapy.org/en/latest/topics/items.html
#
# import scrapy
#
#
# class CrawlerItem(scrapy.Item):
#     # define the fields for your item here like:
#     # name = scrapy.Field()
#     pass

# %%
# %%writefile crawler/crawler/items.py
import scrapy


class CrawlerItem(scrapy.Item):
    title = scrapy.Field()
    s_price = scrapy.Field()
    o_price = scrapy.Field()
    discount_rate = scrapy.Field()
    link = scrapy.Field()
# Out:
# Overwriting crawler/crawler/items.py

# %% [markdown]
# #### 3. spider.py 작성

# %%
# %%writefile crawler/crawler/spiders/spider.py
import scrapy
from crawler.items import CrawlerItem

class Spider(scrapy.Spider):
    name = "GmarketBestsellers" # 이름 값
    allow_domain = ["gmarket.co.kr"]  # 다른 웹 창이 떠도 이 url 것만 크롤링 하겠다.
    start_urls = ["http://corners.gmarket.co.kr/Bestsellers"]  # 최초의 request 해주는 url, 여러개 입력 가능
    
    # start_urls 에 request해서 받은 response로 아래 함수 실행
    def parse(self, response):
        links = response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li/div[1]/a/@href').extract()
        for link in links:
            yield scrapy.Request(link, callback=self.page_content)
    # 함수의 결과데이터가 바로 윗줄의 link로 요청하고 callback 함수를 아래의 함수 이름으로 실행
    
    def page_content(self, response):
        item = CrawlerItem()        
        item["title"] = response.xpath('//*[@id="itemcase_basic"]/h1/text()')[0].extract() 
        item["s_price"] = response.xpath('//*[@id="itemcase_basic"]/p/span/strong/text()')[0].extract().replace(",", "")
        try:
            item["o_price"] = response.xpath('//*[@id="itemcase_basic"]/p/span/span/text()')[0].extract().replace(",", "")
        except:
            item["o_price"] = item["s_price"]
            
        item["discount_rate"] = str(round((1 - int(item["s_price"]) / int(item["o_price"]))*100, 2)) + "%"
        item["link"] = response.url
        yield item
# Out:
# Overwriting crawler/crawler/spiders/spider.py

# %% [markdown]
# #### 4. Scrapy 실행

# %%
# !ls crawler
# Out:
# crawler  scrapy.cfg

# %%
# %%writefile run.sh
# cd crawler
# scrapy crawl GmarketBestsellers
# Out:
# Writing run.sh

# %%
# 실행권한 부여

# %%
# !chmod +x run.sh

# %%
# !./run.sh
# Out:
# 2020-07-02 03:43:51 [scrapy.utils.log] INFO: Scrapy 2.2.0 started (bot: crawler)
# 2020-07-02 03:43:51 [scrapy.utils.log] INFO: Versions: lxml 4.5.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.6.9 (default, Apr 15 2020, 12:56:52) - [GCC 7.5.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.9.2, Platform Linux-5.3.0-1023-aws-x86_64-with-debian-buster-sid
# 2020-07-02 03:43:51 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-07-02 03:43:51 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawler',
#  'NEWSPIDER_MODULE': 'crawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['crawler.spiders']}
# 2020-07-02 03:43:51 [scrapy.extensions.telnet] INFO: Telnet Password: 368e2b1f04c2ce17
# 2020-07-02 03:43:51 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-07-02 03:43:51 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-07-02 03:43:51 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-07-02 03:43:51 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-07-02 03:43:51 [scrapy.core.engine] INFO: Spider opened
# 2020-07-02 03:43:51 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-07-02 03:43:51 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-07-02 03:43:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://corners.gmarket.co.kr/robots.txt> (referer: None)
# 2020-07-02 03:43:51 [protego] DEBUG: Rule at line 3 without any user agent to enforce it on.
# 2020-07-02 03:43:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://corners.gmarket.co.kr/Bestsellers> (referer: None)
# 2020-07-02 03:43:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/robots.txt> (referer: None)
# 2020-07-02 03:43:51 [protego] DEBUG: Rule at line 1 without any user agent to enforce it on.
# 2020-07-02 03:43:51 [protego] DEBUG: Rule at line 2 without any user agent to enforce it on.
# 2020-07-02 03:43:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1759999008&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1158276673&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1291296753&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1759999008&ver=637292906316092197>
# {'discount_rate': '31.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1759999008&ver=637292906316092197',
#  'o_price': '21900',
#  's_price': '14900',
#  'title': '[동원참치] 동원 펭수참치 135g6 + 동원참치135g6 '}
# 2020-07-02 03:43:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1158276673&ver=637292906316092197>
# {'discount_rate': '69.9%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1158276673&ver=637292906316092197',
#  'o_price': '19600',
#  's_price': '5900',
#  'title': '20%쿠폰할인 메이시스 사랑스러운 홈웨어/파자마 '}
# 2020-07-02 03:43:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1291296753&ver=637292906316092197>
# {'discount_rate': '30.28%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1291296753&ver=637292906316092197',
#  'o_price': '14200',
#  's_price': '9900',
#  'title': '햇마루 돈편육 250g X 4팩 '}
# 2020-07-02 03:43:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1784366137&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1784366137&ver=637292906316092197>
# {'discount_rate': '33.33%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1784366137&ver=637292906316092197',
#  'o_price': '39000',
#  's_price': '26000',
#  'title': '[안다르] 패션빅세일 여름안다르 특가2 '}
# 2020-07-02 03:43:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1821541420&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1821541420&ver=637292906316092197>
# {'discount_rate': '69.27%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1821541420&ver=637292906316092197',
#  'o_price': '17900',
#  's_price': '5500',
#  'title': '[스피디] 에어 벤트 차량용 10W 고속 무선충전 거치대 '}
# 2020-07-02 03:43:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1685611499&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1685611499&ver=637292906316092197>
# {'discount_rate': '30.09%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1685611499&ver=637292906316092197',
#  'o_price': '11300',
#  's_price': '7900',
#  'title': '프레시지 삼시세끼 스테이크 (2인) 밀키트 쿠킹박스 '}
# 2020-07-02 03:43:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1503128123&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1503128123&ver=637292906316092197>
# {'discount_rate': '40.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1503128123&ver=637292906316092197',
#  'o_price': '21500',
#  's_price': '12900',
#  'title': '[코코팜] 코코팜 피치핑크 340mlx24캔 '}
# 2020-07-02 03:43:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=929105077&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1373677338&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=876722053&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1542123698&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=929105077&ver=637292906316092197>
# {'discount_rate': '69.9%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=929105077&ver=637292906316092197',
#  'o_price': '19600',
#  's_price': '5900',
#  'title': '3+1 여름 쿨링팬츠/카고바지/와이드/빅사이즈+20%쿠폰 '}
# 2020-07-02 03:43:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1373677338&ver=637292906316092197>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1373677338&ver=637292906316092197',
#  'o_price': '20000',
#  's_price': '10000',
#  'title': '[웨스트우드] 웨스트우드 썸머시즌 티셔츠/팬츠/조끼 베스트전 '}
# 2020-07-02 03:43:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=876722053&ver=637292906316092197>
# {'discount_rate': '38.5%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=876722053&ver=637292906316092197',
#  'o_price': '19350',
#  's_price': '11900',
#  'title': '무염볶음 캐슈넛 400g+400g 견과류 2020년산 '}
# 2020-07-02 03:43:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1542123698&ver=637292906316092197>
# {'discount_rate': '40.09%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1542123698&ver=637292906316092197',
#  'o_price': '23200',
#  's_price': '13900',
#  'title': '[헛개컨디션] CJ 컨디션헛개 75ml x 10병 / 컨디션헛개수 숙취음료 '}
# 2020-07-02 03:43:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1642302984&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1642302984&ver=637292906316092197>
# {'discount_rate': '40.07%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1642302984&ver=637292906316092197',
#  'o_price': '28200',
#  's_price': '16900',
#  'title': '[돌] Dole VF37 오늘맑음 100% 과채즙 야채 주스 120ml 32팩 '}
# 2020-07-02 03:43:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=939528083&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=939528083&ver=637292906316092197>
# {'discount_rate': '63.5%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=939528083&ver=637292906316092197',
#  'o_price': '60000',
#  's_price': '21900',
#  'title': '[한예지] 한예지 볼륨앤소프트 천연펄프 3겹  화장지 30롤 3팩 '}
# 2020-07-02 03:43:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1750698902&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1800726916&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1333899282&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1750698902&ver=637292906316248201>
# {'discount_rate': '5.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1750698902&ver=637292906316248201',
#  'o_price': '10400',
#  's_price': '9880',
#  'title': '[수련] 푹잠발바닥패치SR133 7세트(14매입) 노폐물흡수 패치 '}
# 2020-07-02 03:43:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1800726916&ver=637292906316248201>
# {'discount_rate': '3.95%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1800726916&ver=637292906316248201',
#  'o_price': '11900',
#  's_price': '11430',
#  'title': '무료배송 루다샵/남여공용/커플티/빅사이즈/반팔티 '}
# 2020-07-02 03:43:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1806345360&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1333899282&ver=637292906316248201>
# {'discount_rate': '60.2%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1333899282&ver=637292906316248201',
#  'o_price': '9800',
#  's_price': '3900',
#  'title': '[하이드로더치] 10+10+7 하이드로 더치커피 콜드브루 원두 커피 '}
# 2020-07-02 03:43:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1834219389&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1806345360&ver=637292906316092197>
# {'discount_rate': '14.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1806345360&ver=637292906316092197',
#  'o_price': '34000',
#  's_price': '29240',
#  'title': '[아이더] 갤러리아   2020년 출시제품  엘리 남성 폴로 티셔츠 DMM20281 '}
# 2020-07-02 03:43:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1834219389&ver=637292906316092197>
# {'discount_rate': '37.54%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1834219389&ver=637292906316092197',
#  'o_price': '14250',
#  's_price': '8900',
#  'title': '털 복숭아  1.8kg내외(10과내외)/2개구매시4.5kg발송 '}
# 2020-07-02 03:43:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1566013256&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1831763596&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1566013256&ver=637292906316248201>
# {'discount_rate': '69.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1566013256&ver=637292906316248201',
#  'o_price': '26300',
#  's_price': '7900',
#  'title': '시크루즈/빅세일20%/티셔츠/SET/바지/빅사이즈 '}
# 2020-07-02 03:43:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=809871601&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1831763596&ver=637292906316248201>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1831763596&ver=637292906316248201',
#  'o_price': '46000',
#  's_price': '13800',
#  'title': '브리치x뿌미 여름 best 티셔츠/블라우스/팬츠 '}
# 2020-07-02 03:43:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=809871601&ver=637292906316248201>
# {'discount_rate': '1.45%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=809871601&ver=637292906316248201',
#  'o_price': '13800',
#  's_price': '13600',
#  'title': '[잡잡] 인증검사받은 NBR/TPE 요가 운동 필라테스 매트 용품 '}
# 2020-07-02 03:43:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=197555399&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=197555399&ver=637292906316248201>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=197555399&ver=637292906316248201',
#  'o_price': '33000',
#  's_price': '9900',
#  'title': '투투 빅세일20% 여름 슬랙스/청바지/린넨/반바지 5XL '}
# 2020-07-02 03:43:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1510253190&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:57 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1510253190&ver=637292906316248201>
# {'discount_rate': '40.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1510253190&ver=637292906316248201',
#  'o_price': '21500',
#  's_price': '12900',
#  'title': '[코코팜] 코코팜 포도 340mlx24캔 '}
# 2020-07-02 03:43:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=772056310&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1754993122&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:57 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=772056310&ver=637292906316248201>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=772056310&ver=637292906316248201',
#  'o_price': '46220',
#  's_price': '41600',
#  'title': '[더블에이] 더블에이 A4 복사용지  80g 4000매 2BOX/A4용지 '}
# 2020-07-02 03:43:57 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1754993122&ver=637292906316248201>
# {'discount_rate': '42.47%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1754993122&ver=637292906316248201',
#  'o_price': '25900',
#  's_price': '14900',
#  'title': '[크리넥스] 크리넥스 3겹 데코소프트 33MX24롤화장지/휴지 '}
# 2020-07-02 03:43:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1790000271&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1653023975&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:57 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1790000271&ver=637292906316248201>
# {'discount_rate': '14.57%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1790000271&ver=637292906316248201',
#  'o_price': '34180',
#  's_price': '29200',
#  'title': '[삼성물산] 삼성 프리미엄 그린 A4 복사용지 A4용지 75g 2BOX '}
# 2020-07-02 03:43:57 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1653023975&ver=637292906316248201>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1653023975&ver=637292906316248201',
#  'o_price': '39900',
#  's_price': '39900',
#  'title': '[에이지투웨니스] Age20s 핑크다이아팩트 기획세트 핑크 21호 '}
# 2020-07-02 03:43:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1627193072&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1627193072&ver=637292906316248201>
# {'discount_rate': '4.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1627193072&ver=637292906316248201',
#  'o_price': '12900',
#  's_price': '12260',
#  'title': '[디어베이비] 디어베이비 여름신상 라인반소상하RED GREEN L/PURPLE 02M353093 '}
# 2020-07-02 03:43:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1101182286&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1822934262&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1101182286&ver=637292906316248201>
# {'discount_rate': '30.02%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1101182286&ver=637292906316248201',
#  'o_price': '61300',
#  's_price': '42900',
#  'title': '[맥심] 맥심 모카골드 커피믹스 400T +아이스 콜드컵 증정 '}
# 2020-07-02 03:43:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1833296816&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1822934262&ver=637292906316248201>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1822934262&ver=637292906316248201',
#  'o_price': '16900',
#  's_price': '16900',
#  'title': '[고려은단] 마시는 고려은단 비타민C 1000 100ml 10입X5박스 '}
# 2020-07-02 03:43:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1510254627&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1833296816&ver=637292906316248201>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1833296816&ver=637292906316248201',
#  'o_price': '26900',
#  's_price': '26900',
#  'title': '국내생산) 어썸케어 3중필터 덴탈마스크 50매/일회용 '}
# 2020-07-02 03:43:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1782794055&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=187896486&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1510254627&ver=637292906316248201>
# {'discount_rate': '40.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1510254627&ver=637292906316248201',
#  'o_price': '21500',
#  's_price': '12900',
#  'title': '[코코팜] 코코팜 화이트요구르트 340mlx24캔 '}
# 2020-07-02 03:43:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1782794055&ver=637292906316248201>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1782794055&ver=637292906316248201',
#  'o_price': '43000',
#  's_price': '12900',
#  'title': '[드넬] 드넬 여름신상 특가 티셔츠/원피스/가디건 1만원대 '}
# 2020-07-02 03:43:58 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=187896486&ver=637292906316248201>
# {'discount_rate': '67.59%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=187896486&ver=637292906316248201',
#  'o_price': '39800',
#  's_price': '12900',
#  'title': '14K 피어싱 (Gold-Pin) 1+1 외 쥬얼리 모음전 '}
# 2020-07-02 03:43:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=854297588&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1828653284&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:59 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=854297588&ver=637292906316248201>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=854297588&ver=637292906316248201',
#  'o_price': '55000',
#  's_price': '49500',
#  'title': '[헤라] 헤라 블랙쿠션/파운데이션/선메이트 외 브랜드세일 '}
# 2020-07-02 03:43:59 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1828653284&ver=637292906316248201>
# {'discount_rate': '27.93%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1828653284&ver=637292906316248201',
#  'o_price': '17900',
#  's_price': '12900',
#  'title': '슈퍼대디x미피 소프트플러스 물티슈캡형100매10팩(55g) '}
# 2020-07-02 03:43:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1834213390&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1744769120&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:43:59 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1834213390&ver=637292906316248201>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1834213390&ver=637292906316248201',
#  'o_price': '39000',
#  's_price': '39000',
#  'title': '국산비말차단 나이스오투 여름용 쿨 마스크 대형 50매 '}
# 2020-07-02 03:43:59 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1744769120&ver=637292906316248201>
# {'discount_rate': '40.52%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1744769120&ver=637292906316248201',
#  'o_price': '116000',
#  's_price': '69000',
#  'title': '[제이엠더블유] 에어젯 터보 MS6010A 항공모터 헤어 드라이기 냉풍위크 '}
# 2020-07-02 03:44:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1834459871&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1836164919&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:00 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1834459871&ver=637292906316248201>
# {'discount_rate': '2.51%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1834459871&ver=637292906316248201',
#  'o_price': '39900',
#  's_price': '38900',
#  'title': '어썸핏 시즌2 인견 버뮤다 밴딩 쇼츠 4종 (여성) '}
# 2020-07-02 03:44:00 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1836164919&ver=637292906316248201>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1836164919&ver=637292906316248201',
#  'o_price': '29900',
#  's_price': '29900',
#  'title': '르에어 비말마스크 대형(화이트) KF-ADx30매 (국내산) '}
# 2020-07-02 03:44:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1653469927&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1821572590&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:00 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1653469927&ver=637292906316248201>
# {'discount_rate': '16.76%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1653469927&ver=637292906316248201',
#  'o_price': '17900',
#  's_price': '14900',
#  'title': '[홈스타] 홈스타 뿌리는 곰팡이싹 750ml 4개 + 펑펑 1L '}
# 2020-07-02 03:44:00 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1821572590&ver=637292906316248201>
# {'discount_rate': '20.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1821572590&ver=637292906316248201',
#  'o_price': '99000',
#  's_price': '79200',
#  'title': '[네파키즈] (신세계타임스퀘어점패션관) 아동용 19년 역시즌 남녀공용 제이드 롱 벤치다운 기존가:199 000 '
#           '(KFF2054) '}
# 2020-07-02 03:44:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1104627023&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1825463251&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:00 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1104627023&ver=637292906316248201>
# {'discount_rate': '69.7%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1104627023&ver=637292906316248201',
#  'o_price': '33000',
#  's_price': '10000',
#  'title': '[라벨영] 쇼킹티트리스팟 /여.드름+좁쌀 제거/진정/여 드름패치 '}
# 2020-07-02 03:44:00 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1825463251&ver=637292906316248201>
# {'discount_rate': '7.5%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1825463251&ver=637292906316248201',
#  'o_price': '28000',
#  's_price': '25900',
#  'title': '국산 일회용 마스크 50매 3중 멜트블로운필터 '}
# 2020-07-02 03:44:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1784362444&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=760672691&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1834221128&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1430266775&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:01 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1784362444&ver=637292906316248201>
# {'discount_rate': '11.71%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1784362444&ver=637292906316248201',
#  'o_price': '35000',
#  's_price': '30900',
#  'title': '[안다르] 패션빅세일 여름안다르 특가1 '}
# 2020-07-02 03:44:01 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=760672691&ver=637292906316248201>
# {'discount_rate': '69.98%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=760672691&ver=637292906316248201',
#  'o_price': '46300',
#  's_price': '13900',
#  'title': '시크폭스 여름신상/티셔츠/원피스/팬츠/빅사이즈 '}
# 2020-07-02 03:44:01 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1834221128&ver=637292906316248201>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1834221128&ver=637292906316248201',
#  'o_price': '11900',
#  's_price': '11900',
#  'title': '털 복숭아  1.8kg내외(8과내외)/2개구매시4.5kg발송 '}
# 2020-07-02 03:44:01 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1430266775&ver=637292906316248201>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1430266775&ver=637292906316248201',
#  'o_price': '43000',
#  's_price': '12900',
#  'title': '시크루즈/빅세일20%/원피스/SET아이템/바지/빅사이즈 '}
# 2020-07-02 03:44:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=447292392&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:02 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=447292392&ver=637292906316248201>
# {'discount_rate': '45.04%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=447292392&ver=637292906316248201',
#  'o_price': '63500',
#  's_price': '34900',
#  'title': '[카누] 카누 미니 마일드 120TX2개 총240T : 공유의 커피 ~ '}
# 2020-07-02 03:44:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1828460478&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1608062438&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:02 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1828460478&ver=637292906316248201>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1828460478&ver=637292906316248201',
#  'o_price': '20000',
#  's_price': '18000',
#  'title': '[홍현주,윤재원] 맘 스터디 추천도서 기획전 엄마표 영어 '}
# 2020-07-02 03:44:02 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1608062438&ver=637292906316248201>
# {'discount_rate': '33.33%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1608062438&ver=637292906316248201',
#  'o_price': '20850',
#  's_price': '13900',
#  'title': '[소문난삼부자김] 소문난오부자 전장김25g(8봉+8봉) 선물세트 6월생산 '}
# 2020-07-02 03:44:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1552730555&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:02 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1552730555&ver=637292906316248201>
# {'discount_rate': '41.36%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1552730555&ver=637292906316248201',
#  'o_price': '22000',
#  's_price': '12900',
#  'title': '[마미요] 마미요 오리지널 물티슈 캡형 100매x10팩 '}
# 2020-07-02 03:44:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1103681365&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1103681365&ver=637292906316248201>
# {'discount_rate': '40.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1103681365&ver=637292906316248201',
#  'o_price': '58000',
#  's_price': '34800',
#  'title': '[맥심] 모카골드 커피믹스 160T+160T +비치타월 증정 '}
# 2020-07-02 03:44:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1677547373&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1677547373&ver=637292906316248201>
# {'discount_rate': '54.79%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1677547373&ver=637292906316248201',
#  'o_price': '21900',
#  's_price': '9900',
#  'title': '[바세린] 드라이 스킨 로션 450ml + 드라이 스킨 로션 450ml '}
# 2020-07-02 03:44:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=983182527&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1836010410&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=983182527&ver=637292906316248201>
# {'discount_rate': '14.21%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=983182527&ver=637292906316248201',
#  'o_price': '49540',
#  's_price': '42500',
#  'title': '[더블에이] 더블에이 A4 복사용지(A4용지) 80g 5000매 2BOX '}
# 2020-07-02 03:44:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1836010410&ver=637292906316248201>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1836010410&ver=637292906316248201',
#  'o_price': '43800',
#  's_price': '21900',
#  'title': '[북메카] 북메카 인기 챕터북 모음전 1 '}
# 2020-07-02 03:44:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=133298006&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1107177865&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=133298006&ver=637292906316248201>
# {'discount_rate': '55.71%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=133298006&ver=637292906316248201',
#  'o_price': '35000',
#  's_price': '15500',
#  'title': '[아디다스] 아디다스 나이키外 바캉스 슬리퍼/실내화/샌들 모음 '}
# 2020-07-02 03:44:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1107177865&ver=637292906316248201>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1107177865&ver=637292906316248201',
#  'o_price': '50000',
#  's_price': '15000',
#  'title': '[바닐라코] 바닐라코 여름세일이 왔수박 upto60%/1+1/2+1까지 '}
# 2020-07-02 03:44:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1747419672&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1747419672&ver=637292906316248201>
# {'discount_rate': '16.76%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1747419672&ver=637292906316248201',
#  'o_price': '17900',
#  's_price': '14900',
#  'title': '[Aura] 건조기 럭셔리향수향 아우라 드라이시트 만다린 120매 '}
# 2020-07-02 03:44:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1746750802&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1746750802&ver=637292906316248201>
# {'discount_rate': '23.17%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1746750802&ver=637292906316248201',
#  'o_price': '25900',
#  's_price': '19900',
#  'title': '[농심] 앵그리 짜파구리 30봉 (RTA15+짜파게티15) '}
# 2020-07-02 03:44:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1783367530&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1246494669&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1783367530&ver=637292906316248201>
# {'discount_rate': '3.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1783367530&ver=637292906316248201',
#  'o_price': '50000',
#  's_price': '48500',
#  'title': '[에쓰오일] (S-OIL) 모바일주유권 5만원/ 실시간발송/ 주유상품권 '}
# 2020-07-02 03:44:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1246494669&ver=637292906316248201>
# {'discount_rate': '60.07%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1246494669&ver=637292906316248201',
#  'o_price': '29800',
#  's_price': '11900',
#  'title': '[아르페지오베이직] 빨아쓰는 굿슬립 워셔블베개/경추베개/기능성베개솜 '}
# 2020-07-02 03:44:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1802592729&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1802592729&ver=637292906316248201>
# {'discount_rate': '3.95%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1802592729&ver=637292906316248201',
#  'o_price': '11900',
#  's_price': '11430',
#  'title': '다다샵 남여공용/반팔티/커플티/전사나염/티셔츠 '}
# 2020-07-02 03:44:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1321028651&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1834355536&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1321028651&ver=637292906316248201>
# {'discount_rate': '68.33%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1321028651&ver=637292906316248201',
#  'o_price': '30000',
#  's_price': '9500',
#  'title': 'NEW땡큐 화장지 (30롤 x 2팩) / 3겹 두루마리 휴지 '}
# 2020-07-02 03:44:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1686035302&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1834355536&ver=637292906316248201>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1834355536&ver=637292906316248201',
#  'o_price': '22900',
#  's_price': '22900',
#  'title': '이동수 프리모션 골프 팬츠 1+1 '}
# 2020-07-02 03:44:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1686035302&ver=637292906316248201>
# {'discount_rate': '4.03%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1686035302&ver=637292906316248201',
#  'o_price': '12400',
#  's_price': '11900',
#  'title': '[제주삼다수] 제주삼다수 2L 12병/생수전문배송 '}
# 2020-07-02 03:44:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=169295221&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=169295221&ver=637292906316248201>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=169295221&ver=637292906316248201',
#  'o_price': '46000',
#  's_price': '13800',
#  'title': '신상/남자청바지/남성/빅사이즈/스판/바지/슬랙스 '}
# 2020-07-02 03:44:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1817490375&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1822656897&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:06 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1817490375&ver=637292906316248201>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1817490375&ver=637292906316248201',
#  'o_price': '26900',
#  's_price': '24210',
#  'title': '[다우니] 다우니 퍼플 1L 화이트티와 릴리 향 6개 +사은품 '}
# 2020-07-02 03:44:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1583809257&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:06 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1822656897&ver=637292906316248201>
# {'discount_rate': '17.38%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1822656897&ver=637292906316248201',
#  'o_price': '20540',
#  's_price': '16970',
#  'title': '[켈로그] 첵스초코 3종(쿠키앤크림+스노우+마시멜로) '}
# 2020-07-02 03:44:06 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1583809257&ver=637292906316248201>
# {'discount_rate': '66.83%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1583809257&ver=637292906316248201',
#  'o_price': '60000',
#  's_price': '19900',
#  'title': '[하비비] 청개구리 자동 변기 클리너 세정제 6개 (12개월분) '}
# 2020-07-02 03:44:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1477758315&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1285585775&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:06 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1477758315&ver=637292906316248201>
# {'discount_rate': '63.94%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1477758315&ver=637292906316248201',
#  'o_price': '33000',
#  's_price': '11900',
#  'title': '[케이스위스] 케이스위스/르까프 트레이닝 세트/티셔츠/쇼츠 '}
# 2020-07-02 03:44:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1833200917&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:06 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1285585775&ver=637292906316248201>
# {'discount_rate': '42.45%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1285585775&ver=637292906316248201',
#  'o_price': '41700',
#  's_price': '24000',
#  'title': '[세컨스킨] 베이직 삼각팬티 3종 E8GKU7005 인생팬티~ '}
# 2020-07-02 03:44:06 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1833200917&ver=637292906316248201>
# {'discount_rate': '20.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1833200917&ver=637292906316248201',
#  'o_price': '129500',
#  's_price': '103600',
#  'title': '[디스커버리] (신세계경기점) 19F/W  디스커버리 역시즌 키즈 레스터 G 벤치 롱 구스다운자켓 DKDJ54961 '}
# 2020-07-02 03:44:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1830270736&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:06 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1830270736&ver=637292906316248201>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1830270736&ver=637292906316248201',
#  'o_price': '36900',
#  's_price': '36900',
#  'title': '모다아울렛  라코스테 데일리룩의 기본 로고반팔/프린팅 BEST세일 '}
# 2020-07-02 03:44:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1543495365&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1543495365&ver=637292906316248201>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1543495365&ver=637292906316248201',
#  'o_price': '6900',
#  's_price': '6900',
#  'title': '종이컵 1000개 한박스(사업자반값상품) '}
# 2020-07-02 03:44:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1822327700&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=769284968&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1822327700&ver=637292906316248201>
# {'discount_rate': '13.48%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1822327700&ver=637292906316248201',
#  'o_price': '23000',
#  's_price': '19900',
#  'title': '[엘르이너웨어] 여름엔 스킨 브라팬티 6종택1 EPB16052EPH16052-6 '}
# 2020-07-02 03:44:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=769284968&ver=637292906316248201>
# {'discount_rate': '69.62%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=769284968&ver=637292906316248201',
#  'o_price': '26000',
#  's_price': '7900',
#  'title': '[라벨영] 호랑이 비누 1+1 /민감피부용/병풀추출물 '}
# 2020-07-02 03:44:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=900637906&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:07 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=900637906&ver=637292906316248201>
# {'discount_rate': '69.93%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=900637906&ver=637292906316248201',
#  'o_price': '29600',
#  's_price': '8900',
#  'title': '[삠뽀요] 여름SALE 추가쿠폰/실내복/상하복/원피스/티/팬츠 '}
# 2020-07-02 03:44:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1818930342&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1287247888&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1833804071&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1818930342&ver=637292906316248201>
# {'discount_rate': '38.5%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1818930342&ver=637292906316248201',
#  'o_price': '19350',
#  's_price': '11900',
#  'title': '[바라던] 꼭 한번 먹어봐야 할 이베리코 목살 200g 3팩.증정행사 '}
# 2020-07-02 03:44:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1287247888&ver=637292906316248201>
# {'discount_rate': '37.14%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1287247888&ver=637292906316248201',
#  'o_price': '15750',
#  's_price': '9900',
#  'title': '[너트리] 캘리포니아 볶음아몬드 500g x 2개 19년산 '}
# 2020-07-02 03:44:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1833804071&ver=637292906316248201>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1833804071&ver=637292906316248201',
#  'o_price': '54000',
#  's_price': '54000',
#  'title': '(재탄생 이벤트) 생각이 열리는 마음그림책 전25권(작은철학자 재탄생) / 행복뿜뿜 (선택구매) '}
# 2020-07-02 03:44:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1510637585&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1649456622&ver=637292906316248201> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:08 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1510637585&ver=637292906316248201>
# {'discount_rate': '40.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1510637585&ver=637292906316248201',
#  'o_price': '25000',
#  's_price': '15000',
#  'title': '[스파클] 스파클생수 2L 30병 '}
# ...
# {'discount_rate': '3.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1782687491&ver=637292906316092197',
#  'o_price': '50000',
#  's_price': '48500',
#  'title': '[에쓰오일] (S-OIL) 모바일 주유권 5만원권 '}
# 2020-07-02 03:44:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1419081053&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1419081053&ver=637292906316092197>
# {'discount_rate': '44.72%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1419081053&ver=637292906316092197',
#  'o_price': '36000',
#  's_price': '19900',
#  'title': '[크록스] (정품)크록스 크록밴드 인기 샌들 모음 '}
# 2020-07-02 03:44:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1788177969&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1788177969&ver=637292906316092197>
# {'discount_rate': '8.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1788177969&ver=637292906316092197',
#  'o_price': '28000',
#  's_price': '25760',
#  'title': '루이까또즈 햇빛차단 백화점상품 양산특가 '}
# 2020-07-02 03:44:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1687057776&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1807191272&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1687057776&ver=637292906316092197>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1687057776&ver=637292906316092197',
#  'o_price': '27900',
#  's_price': '27900',
#  'title': '(etv)목우촌 무항생제 훈제오리 200gX10팩 (총 2kg) '}
# 2020-07-02 03:44:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1807191272&ver=637292906316092197>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1807191272&ver=637292906316092197',
#  'o_price': '38000',
#  's_price': '19000',
#  'title': '이니스프리 썸머 수퍼패키지+BEST템 최대 50%할인전 '}
# 2020-07-02 03:44:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=495818668&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1792799595&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=495818668&ver=637292906316092197>
# {'discount_rate': '69.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=495818668&ver=637292906316092197',
#  'o_price': '26300',
#  's_price': '7900',
#  'title': '[젤리스푼] 아동복/아동의류/여아원피스/상하복/실내복/여름옷 '}
# 2020-07-02 03:44:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1792799595&ver=637292906316092197>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1792799595&ver=637292906316092197',
#  'o_price': '49900',
#  's_price': '49900',
#  'title': '론칭가 79900원 엣지 SUMMER20 워싱 코튼 원피스2종 '}
# 2020-07-02 03:44:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1722135077&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1722135077&ver=637292906316092197>
# {'discount_rate': '69.98%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1722135077&ver=637292906316092197',
#  'o_price': '41300',
#  's_price': '12400',
#  'title': '스타스텝 20%쿠폰 빅사이즈/원피스/티셔츠/세트 '}
# 2020-07-02 03:44:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1792532819&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1792532819&ver=637292906316092197>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1792532819&ver=637292906316092197',
#  'o_price': '49000',
#  's_price': '49000',
#  'title': '라포프  썸머 깅엄체크 코튼 블라우스 3종 '}
# 2020-07-02 03:44:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1516427212&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1516427212&ver=637292906316092197>
# {'discount_rate': '15.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1516427212&ver=637292906316092197',
#  'o_price': '10000',
#  's_price': '8500',
#  'title': '[2080] 2080 어린이치약 키즈크리닉 순한민트 80gx5개 '}
# 2020-07-02 03:44:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=861577112&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=861577112&ver=637292906316092197>
# {'discount_rate': '69.93%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=861577112&ver=637292906316092197',
#  'o_price': '29600',
#  's_price': '8900',
#  'title': '[이사도라] 여름 신상 뮬슬리퍼 젤리슈즈 뮬스니커즈 '}
# 2020-07-02 03:44:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1666944408&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1824655023&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1544164687&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1666944408&ver=637292906316092197>
# {'discount_rate': '31.75%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1666944408&ver=637292906316092197',
#  'o_price': '18900',
#  's_price': '12900',
#  'title': '[파스퇴르우유] 무항생제 바른목장 우유 190ml/24팩 /유통기한 8.11 '}
# 2020-07-02 03:44:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1824655023&ver=637292906316092197>
# {'discount_rate': '21.99%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1824655023&ver=637292906316092197',
#  'o_price': '69900',
#  's_price': '54530',
#  'title': '[아디다스오리지널] (신세계마산점) MENS ORIGINALS  슈퍼스타/팔콘 8종 (EG4958 FW2293 '
#           'EG4960 FW7051 B28129 FW6384 FV281... '}
# 2020-07-02 03:44:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1544164687&ver=637292906316092197>
# {'discount_rate': '39.06%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1544164687&ver=637292906316092197',
#  'o_price': '32000',
#  's_price': '19500',
#  'title': '[나이키키즈] 20%추가쿠폰 나이키/리바이스 키즈/주니어 여름 SALE '}
# 2020-07-02 03:44:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1787960274&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1345149344&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1787960274&ver=637292906316092197>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1787960274&ver=637292906316092197',
#  'o_price': '46000',
#  's_price': '13800',
#  'title': '브리치x한미미 20%+7%쿠폰 티셔츠/블라우스/원피스 '}
# 2020-07-02 03:44:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1345149344&ver=637292906316092197>
# {'discount_rate': '69.98%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1345149344&ver=637292906316092197',
#  'o_price': '46300',
#  's_price': '13900',
#  'title': '브리치x럭키567 20%+7%쿠폰 반팔/블라우스/원피스 '}
# 2020-07-02 03:44:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1583097834&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1583097834&ver=637292906316092197>
# {'discount_rate': '69.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1583097834&ver=637292906316092197',
#  'o_price': '49600',
#  's_price': '14900',
#  'title': '브리치x아이미마인 20%+7%쿠폰 반팔/블라우스/원피스 '}
# 2020-07-02 03:44:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=751249829&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=751249829&ver=637292906316092197>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=751249829&ver=637292906316092197',
#  'o_price': '23000',
#  's_price': '6900',
#  'title': '쏭스타일 롱티.루즈핏.박스티.신상특가 '}
# 2020-07-02 03:44:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=767588368&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1285565414&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=767588368&ver=637292906316092197>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=767588368&ver=637292906316092197',
#  'o_price': '33000',
#  's_price': '9900',
#  'title': '14K귀걸이(Gold-Pin) 외 로즈골드 쥬얼리 특가전 '}
# 2020-07-02 03:44:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1285565414&ver=637292906316092197>
# {'discount_rate': '7.52%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1285565414&ver=637292906316092197',
#  'o_price': '6380',
#  's_price': '5900',
#  'title': '콩나물 재배기 + 국산콩증정 '}
# 2020-07-02 03:44:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1820926820&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1836263711&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1820926820&ver=637292906316092197>
# {'discount_rate': '9.17%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1820926820&ver=637292906316092197',
#  'o_price': '10900',
#  's_price': '9900',
#  'title': '국내 인증 일회용마스크 50매 화이트 멜트블로운 필터 '}
# 2020-07-02 03:44:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1836263711&ver=637292906316092197>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1836263711&ver=637292906316092197',
#  'o_price': '25000',
#  's_price': '22500',
#  'title': '[아이더] (현대백화점)아이더 남성 트위스팅 폴로 티셔츠 '}
# 2020-07-02 03:44:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1685460952&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1620413379&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:28 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1685460952&ver=637292906316092197>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1685460952&ver=637292906316092197',
#  'o_price': '33500',
#  's_price': '33500',
#  'title': '모다아울렛 타미힐피거 반팔카라티 최대할인전 '}
# 2020-07-02 03:44:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=635067641&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:28 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1620413379&ver=637292906316092197>
# {'discount_rate': '35.64%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1620413379&ver=637292906316092197',
#  'o_price': '43350',
#  's_price': '27900',
#  'title': '키위 제스프리 골드 키위 특대과 30과 '}
# 2020-07-02 03:44:28 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=635067641&ver=637292906316092197>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=635067641&ver=637292906316092197',
#  'o_price': '56000',
#  's_price': '16800',
#  'title': '[난닝구] 20%쿠폰 난닝구 여름SALE 티셔츠/원피스 (5만무배) '}
# 2020-07-02 03:44:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1830306098&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:28 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1830306098&ver=637292906316092197>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1830306098&ver=637292906316092197',
#  'o_price': '36900',
#  's_price': '36900',
#  'title': '동아 전과 / 백점 국과사/ 백점 전과목 세트 2학기 선택구매 (1-2. 2-2. 3-2. 4-2. 5-2. 6-2) '}
# 2020-07-02 03:44:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1836050674&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:28 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1836050674&ver=637292906316092197>
# {'discount_rate': '20.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1836050674&ver=637292906316092197',
#  'o_price': '27800',
#  's_price': '22240',
#  'title': '국내생산 FDA 승인 귀가 편한 3중필터 마스크 50매 '}
# 2020-07-02 03:44:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1792465372&ver=637292906316092197> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 03:44:28 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1792465372&ver=637292906316092197>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1792465372&ver=637292906316092197',
#  'o_price': '21900',
#  's_price': '21900',
#  'title': '[ahc] AHC 더퓨어 아이크림 30ml 4개 + 3종 키트 증정 '}
# 2020-07-02 03:44:28 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-07-02 03:44:28 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 74928,
#  'downloader/request_count': 203,
#  'downloader/request_method_count/GET': 203,
#  'downloader/response_bytes': 7673339,
#  'downloader/response_count': 203,
#  'downloader/response_status_count/200': 203,
#  'elapsed_time_seconds': 37.398718,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 7, 2, 3, 44, 28, 865079),
#  'item_scraped_count': 200,
#  'log_count/DEBUG': 406,
#  'log_count/INFO': 10,
#  'memusage/max': 55484416,
#  'memusage/startup': 55484416,
#  'request_depth_max': 1,
#  'response_received_count': 203,
#  'robotstxt/request_count': 2,
#  'robotstxt/response_count': 2,
#  'robotstxt/response_status_count/200': 2,
#  'scheduler/dequeued': 201,
#  'scheduler/dequeued/memory': 201,
#  'scheduler/enqueued': 201,
#  'scheduler/enqueued/memory': 201,
#  'start_time': datetime.datetime(2020, 7, 2, 3, 43, 51, 466361)}
# 2020-07-02 03:44:28 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# %load crawler/crawler/spiders/spider.py

# %%
# %load crawler/crawler/spiders/spider.py
import scrapy
from crawler.items import CrawlerItem

class Spider(scrapy.Spider):
    name = "GmarketBestsellers" # 이름 값
    allow_domain = ["gmarket.co.kr"]  # 다른 웹 창이 떠도 이 url 것만 크롤링 하겠다.
    start_urls = ["http://corners.gmarket.co.kr/Bestsellers"]  # 최초의 request 해주는 url, 여러개 입력 가능
    
    # start_urls 에 request해서 받은 response로 아래 함수 실행
    def parse(self, response):
        links = response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li/div[1]/a/@href').extract()
        for link in links:
            yield scrapy.Request(link, callback=self.page_content)
    # 함수의 결과데이터가 바로 윗줄의 link로 요청하고 callback 함수를 아래의 함수 이름으로 실행
    
    def page_content(self, response):
        item = CrawlerItem()        
        item["title"] = response.xpath('//*[@id="itemcase_basic"]/h1/text()')[0].extract() 
        item["s_price"] = response.xpath('//*[@id="itemcase_basic"]/p/span/strong/text()')[0].extract().replace(",", "")
        try:
            item["o_price"] = response.xpath('//*[@id="itemcase_basic"]/p/span/span/text()')[0].extract().replace(",", "")
        except:
            item["o_price"] = item["s_price"]
            
        item["discount_rate"] = str(round((1 - int(item["s_price"]) / int(item["o_price"]))*100, 2)) + "%"
        item["link"] = response.url
        yield item

# %% [markdown]
# - 결과를 csv로 저장
# - csv 파일에 ',' 있으면 깨짐. replace 해주는게 좋음

# %%
# %%writefile run.sh
# cd crawler
# scrapy crawl GmarketBestsellers -o GmarketBestsellers.csv
# Out:
# Overwriting run.sh

# %%
# !./run.sh
# Out:
# 2020-07-02 04:47:38 [scrapy.utils.log] INFO: Scrapy 2.2.0 started (bot: crawler)
# 2020-07-02 04:47:38 [scrapy.utils.log] INFO: Versions: lxml 4.5.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.6.9 (default, Apr 15 2020, 12:56:52) - [GCC 7.5.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.9.2, Platform Linux-5.3.0-1023-aws-x86_64-with-debian-buster-sid
# 2020-07-02 04:47:38 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-07-02 04:47:38 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawler',
#  'NEWSPIDER_MODULE': 'crawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['crawler.spiders']}
# 2020-07-02 04:47:38 [scrapy.extensions.telnet] INFO: Telnet Password: 93e91ce482f4da34
# 2020-07-02 04:47:38 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-07-02 04:47:38 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-07-02 04:47:38 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-07-02 04:47:38 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-07-02 04:47:38 [scrapy.core.engine] INFO: Spider opened
# 2020-07-02 04:47:38 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-07-02 04:47:38 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-07-02 04:47:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://corners.gmarket.co.kr/robots.txt> (referer: None)
# 2020-07-02 04:47:39 [protego] DEBUG: Rule at line 3 without any user agent to enforce it on.
# 2020-07-02 04:47:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://corners.gmarket.co.kr/Bestsellers> (referer: None)
# 2020-07-02 04:47:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/robots.txt> (referer: None)
# 2020-07-02 04:47:39 [protego] DEBUG: Rule at line 1 without any user agent to enforce it on.
# 2020-07-02 04:47:39 [protego] DEBUG: Rule at line 2 without any user agent to enforce it on.
# 2020-07-02 04:47:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1759999008&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1784366137&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1373677338&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1158276673&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:40 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1759999008&ver=637292944591108578>
# {'discount_rate': '18.26%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1759999008&ver=637292944591108578',
#  'o_price': '21900',
#  's_price': '17900',
#  'title': '[동원참치] 동원 펭수참치 135g6 + 동원참치135g6 '}
# 2020-07-02 04:47:40 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1784366137&ver=637292944591108578>
# {'discount_rate': '33.33%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1784366137&ver=637292944591108578',
#  'o_price': '39000',
#  's_price': '26000',
#  'title': '[안다르] 패션빅세일 여름안다르 특가2 '}
# 2020-07-02 04:47:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1824655023&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=495818668&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:40 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1373677338&ver=637292944591108578>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1373677338&ver=637292944591108578',
#  'o_price': '20000',
#  's_price': '10000',
#  'title': '[웨스트우드] 웨스트우드 썸머시즌 티셔츠/팬츠/조끼 베스트전 '}
# 2020-07-02 04:47:40 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1158276673&ver=637292944591108578>
# {'discount_rate': '69.9%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1158276673&ver=637292944591108578',
#  'o_price': '19600',
#  's_price': '5900',
#  'title': '20%쿠폰할인 메이시스 사랑스러운 홈웨어/파자마 '}
# 2020-07-02 04:47:40 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1824655023&ver=637292944591108578>
# {'discount_rate': '21.99%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1824655023&ver=637292944591108578',
#  'o_price': '69900',
#  's_price': '54530',
#  'title': '[아디다스오리지널] (신세계마산점) MENS ORIGINALS  슈퍼스타/팔콘 8종 (EG4958 FW2293 '
#           'EG4960 FW7051 B28129 FW6384 FV281... '}
# 2020-07-02 04:47:40 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=495818668&ver=637292944591108578>
# {'discount_rate': '69.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=495818668&ver=637292944591108578',
#  'o_price': '26300',
#  's_price': '7900',
#  'title': '[젤리스푼] 아동복/아동의류/여아원피스/상하복/실내복/여름옷 '}
# 2020-07-02 04:47:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1821541420&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1821541420&ver=637292944591108578>
# {'discount_rate': '69.27%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1821541420&ver=637292944591108578',
#  'o_price': '17900',
#  's_price': '5500',
#  'title': '[스피디] 에어 벤트 차량용 10W 고속 무선충전 거치대 '}
# 2020-07-02 04:47:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1806345360&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1806345360&ver=637292944591108578>
# {'discount_rate': '14.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1806345360&ver=637292944591108578',
#  'o_price': '34000',
#  's_price': '29240',
#  'title': '[아이더] 갤러리아   2020년 출시제품  엘리 남성 폴로 티셔츠 DMM20281 '}
# 2020-07-02 04:47:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1291296753&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1291296753&ver=637292944591108578>
# {'discount_rate': '30.28%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1291296753&ver=637292944591108578',
#  'o_price': '14200',
#  's_price': '9900',
#  'title': '햇마루 돈편육 250g X 4팩 '}
# 2020-07-02 04:47:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1544164687&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1544164687&ver=637292944591108578>
# {'discount_rate': '39.06%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1544164687&ver=637292944591108578',
#  'o_price': '32000',
#  's_price': '19500',
#  'title': '[나이키키즈] 20%추가쿠폰 나이키/리바이스 키즈/주니어 여름 SALE '}
# 2020-07-02 04:47:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=876722053&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=876722053&ver=637292944591108578>
# {'discount_rate': '38.5%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=876722053&ver=637292944591108578',
#  'o_price': '19350',
#  's_price': '11900',
#  'title': '무염볶음 캐슈넛 400g+400g 견과류 2020년산 '}
# 2020-07-02 04:47:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=939528083&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:42 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=939528083&ver=637292944591108578>
# {'discount_rate': '63.5%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=939528083&ver=637292944591108578',
#  'o_price': '60000',
#  's_price': '21900',
#  'title': '[한예지] 한예지 볼륨앤소프트 천연펄프 3겹  화장지 30롤 3팩 '}
# 2020-07-02 04:47:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1666944408&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1754993122&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:42 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1666944408&ver=637292944591108578>
# {'discount_rate': '31.75%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1666944408&ver=637292944591108578',
#  'o_price': '18900',
#  's_price': '12900',
#  'title': '[파스퇴르우유] 무항생제 바른목장 우유 190ml/24팩 /유통기한 8.11 '}
# 2020-07-02 04:47:42 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1754993122&ver=637292944591264582>
# {'discount_rate': '42.47%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1754993122&ver=637292944591264582',
#  'o_price': '25900',
#  's_price': '14900',
#  'title': '[크리넥스] 크리넥스 3겹 데코소프트 33MX24롤화장지/휴지 '}
# 2020-07-02 04:47:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1642302984&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:42 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1642302984&ver=637292944591108578>
# {'discount_rate': '40.07%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1642302984&ver=637292944591108578',
#  'o_price': '28200',
#  's_price': '16900',
#  'title': '[돌] Dole VF37 오늘맑음 100% 과채즙 야채 주스 120ml 32팩 '}
# 2020-07-02 04:47:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1685611499&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:42 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1685611499&ver=637292944591108578>
# {'discount_rate': '30.09%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1685611499&ver=637292944591108578',
#  'o_price': '11300',
#  's_price': '7900',
#  'title': '프레시지 삼시세끼 스테이크 (2인) 밀키트 쿠킹박스 '}
# 2020-07-02 04:47:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1830250115&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=809871601&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1830250115&ver=637292944591264582>
# {'discount_rate': '25.06%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1830250115&ver=637292944591264582',
#  'o_price': '39900',
#  's_price': '29900',
#  'title': '[에어퀸] 미국 FDA 승인 에어퀸 나노 마스크 30매 대형 개별포장 '}
# 2020-07-02 04:47:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1104627023&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=809871601&ver=637292944591264582>
# {'discount_rate': '1.45%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=809871601&ver=637292944591264582',
#  'o_price': '13800',
#  's_price': '13600',
#  'title': '[잡잡] 인증검사받은 NBR/TPE 요가 운동 필라테스 매트 용품 '}
# 2020-07-02 04:47:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1104627023&ver=637292944591264582>
# {'discount_rate': '69.7%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1104627023&ver=637292944591264582',
#  'o_price': '33000',
#  's_price': '10000',
#  'title': '[라벨영] 쇼킹티트리스팟 /여.드름+좁쌀 제거/진정/여 드름패치 '}
# 2020-07-02 04:47:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1295855591&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1295855591&ver=637292944591264582>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1295855591&ver=637292944591264582',
#  'o_price': '23000',
#  's_price': '6900',
#  'title': '[에비수] 에비수 브랜드 반팔티/티셔츠/반바지/청바지 '}
# 2020-07-02 04:47:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1833666032&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1833666032&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1833666032&ver=637292944591264582',
#  'o_price': '19900',
#  's_price': '19900',
#  'title': '[티에뉴] LED 미니 휴대용 핸디 손 선풍기 망치 선풍기 1+1 '}
# 2020-07-02 04:47:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=901925478&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=901925478&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=901925478&ver=637292944591264582',
#  'o_price': '20200',
#  's_price': '20200',
#  'title': '[팜파스] 무형광 미쁘 핸드타올  2겹5000매 페이퍼타올 핸드타월 '}
# 2020-07-02 04:47:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1161403967&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1161403967&ver=637292944591264582>
# {'discount_rate': '69.93%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1161403967&ver=637292944591264582',
#  'o_price': '29600',
#  's_price': '8900',
#  'title': '[뱅뱅] 뱅뱅인터크루 중복할인~20%+12%/썸머특가/반팔/반바지 '}
# 2020-07-02 04:47:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1800150999&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1653023975&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1800150999&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1800150999&ver=637292944591264582',
#  'o_price': '49000',
#  's_price': '49000',
#  'title': '기존가79000 엣지 SUMMER20 린넨블렌디드 체크자켓 '}
# 2020-07-02 04:47:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1653023975&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1653023975&ver=637292944591264582',
#  'o_price': '39900',
#  's_price': '39900',
#  'title': '[에이지투웨니스] Age20s 핑크다이아팩트 기획세트 핑크 21호 '}
# 2020-07-02 04:47:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=447292392&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=447292392&ver=637292944591264582>
# {'discount_rate': '45.04%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=447292392&ver=637292944591264582',
#  'o_price': '63500',
#  's_price': '34900',
#  'title': '[카누] 카누 미니 마일드 120TX2개 총240T : 공유의 커피 ~ '}
# 2020-07-02 04:47:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1822671835&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1517719492&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1822671835&ver=637292944591264582>
# {'discount_rate': '20.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1822671835&ver=637292944591264582',
#  'o_price': '27000',
#  's_price': '21600',
#  'title': '[버커루] 남여 청바지 10종 택1 (B195Z0132P외 9종) '}
# 2020-07-02 04:47:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1517719492&ver=637292944591264582>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1517719492&ver=637292944591264582',
#  'o_price': '33000',
#  's_price': '9900',
#  'title': '쿠폰20% 균일가 원피스/블라우스/여름니트 빅사이즈 '}
# 2020-07-02 04:47:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1825116088&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1825116088&ver=637292944591264582>
# {'discount_rate': '6.97%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1825116088&ver=637292944591264582',
#  'o_price': '99000',
#  's_price': '92100',
#  'title': '[아디다스] 아디다스(adidas) 테크 레볼루션 드로즈 패키지 9종 (50차) '}
# 2020-07-02 04:47:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1800726916&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1800726916&ver=637292944591264582>
# {'discount_rate': '3.95%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1800726916&ver=637292944591264582',
#  'o_price': '11900',
#  's_price': '11430',
#  'title': '무료배송 루다샵/남여공용/커플티/빅사이즈/반팔티 '}
# 2020-07-02 04:47:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1350339365&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1350339365&ver=637292944591264582>
# {'discount_rate': '69.88%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1350339365&ver=637292944591264582',
#  'o_price': '83000',
#  's_price': '25000',
#  'title': '[지오다노] 지오다노 시즌오프+빅세일 셔츠/린넨/슬랙스 최대특가 '}
# 2020-07-02 04:47:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=782096663&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=782096663&ver=637292944591264582>
# {'discount_rate': '14.09%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=782096663&ver=637292944591264582',
#  'o_price': '36550',
#  's_price': '31400',
#  'title': '[HP] HP A4 복사용지(A4용지) 80g 2500매 2BOX/더블에이 '}
# 2020-07-02 04:47:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1805969711&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1744769120&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1805969711&ver=637292944591264582>
# {'discount_rate': '12.04%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1805969711&ver=637292944591264582',
#  'o_price': '49000',
#  's_price': '43100',
#  'title': '위드블루 여성 쿨맥스 슬림 보이핏데님 팬츠 2종 '}
# 2020-07-02 04:47:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1285585775&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1744769120&ver=637292944591264582>
# {'discount_rate': '40.52%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1744769120&ver=637292944591264582',
#  'o_price': '116000',
#  's_price': '69000',
#  'title': '[제이엠더블유] 에어젯 터보 MS6010A 항공모터 헤어 드라이기 냉풍위크 '}
# 2020-07-02 04:47:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1285585775&ver=637292944591264582>
# {'discount_rate': '42.45%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1285585775&ver=637292944591264582',
#  'o_price': '41700',
#  's_price': '24000',
#  'title': '[세컨스킨] 베이직 삼각팬티 3종 E8GKU7005 인생팬티~ '}
# 2020-07-02 04:47:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1833804071&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1833804071&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1833804071&ver=637292944591264582',
#  'o_price': '54000',
#  's_price': '54000',
#  'title': '(재탄생 이벤트) 생각이 열리는 마음그림책 전25권(작은철학자 재탄생) / 행복뿜뿜 (선택구매) '}
# 2020-07-02 04:47:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1785755883&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1835846395&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1819964769&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1785755883&ver=637292944591264582>
# {'discount_rate': '35.65%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1785755883&ver=637292944591264582',
#  'o_price': '62000',
#  's_price': '39900',
#  'title': '브라이트닝 업 선 플러스 SPF50+ PA+++ 50ml 듀오 '}
# 2020-07-02 04:47:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1835846395&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1835846395&ver=637292944591264582',
#  'o_price': '314000',
#  's_price': '314000',
#  'title': '(유아동과학 베스트특가) Howso교과융합과학탐구 / 사이언스Howso : 옵션선택 '}
# 2020-07-02 04:47:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1819964769&ver=637292944591264582>
# {'discount_rate': '12.56%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1819964769&ver=637292944591264582',
#  'o_price': '39000',
#  's_price': '34100',
#  'title': 'NNF 엔엔에프  텐셀 이지 숏 팬츠 3종 '}
# 2020-07-02 04:47:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1549934150&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1835839012&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1830270736&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1549934150&ver=637292944591264582>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1549934150&ver=637292944591264582',
#  'o_price': '35800',
#  's_price': '17900',
#  'title': '[맥심] 맥심 모카골드 솔루블 블랙커피100T+100T '}
# 2020-07-02 04:47:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1835839012&ver=637292944591264582>
# {'discount_rate': '7.15%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1835839012&ver=637292944591264582',
#  'o_price': '52000',
#  's_price': '48280',
#  'title': '푸른날개 어린이 수업 시리즈/단서를 찾아라 선택구매 '}
# 2020-07-02 04:47:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1830270736&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1830270736&ver=637292944591264582',
#  'o_price': '36900',
#  's_price': '36900',
#  'title': '모다아울렛  라코스테 데일리룩의 기본 로고반팔/프린팅 BEST세일 '}
# 2020-07-02 04:47:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1333899282&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1333899282&ver=637292944591264582>
# {'discount_rate': '60.2%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1333899282&ver=637292944591264582',
#  'o_price': '9800',
#  's_price': '3900',
#  'title': '[하이드로더치] 10+10+7 하이드로 더치커피 콜드브루 원두 커피 '}
# 2020-07-02 04:47:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1820821824&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1782907745&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1820821824&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1820821824&ver=637292944591264582',
#  'o_price': '49500',
#  's_price': '49500',
#  'title': '휴안청프레시 70 KF AD 50매 식약처인증 국산 일회용 KFAD 비말차단 마스크 (freah 0601) '}
# 2020-07-02 04:47:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1782907745&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1782907745&ver=637292944591264582',
#  'o_price': '7400',
#  's_price': '7400',
#  'title': '[크리넥스] 수앤수 코튼클린 물티슈 베이직 캡형 72매10팩 BIZ. '}
# 2020-07-02 04:47:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1583809257&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1583809257&ver=637292944591264582>
# {'discount_rate': '66.83%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1583809257&ver=637292944591264582',
#  'o_price': '60000',
#  's_price': '19900',
#  'title': '[하비비] 청개구리 자동 변기 클리너 세정제 6개 (12개월분) '}
# 2020-07-02 04:47:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=197555399&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1543095376&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1781618194&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1811563066&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=197555399&ver=637292944591264582>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=197555399&ver=637292944591264582',
#  'o_price': '33000',
#  's_price': '9900',
#  'title': '투투 빅세일20% 여름 슬랙스/청바지/린넨/반바지 5XL '}
# 2020-07-02 04:47:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1543095376&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1543095376&ver=637292944591264582',
#  'o_price': '25900',
#  's_price': '25900',
#  'title': '[BYO] CJ BYO 20억 생유산균 30포 x 3개 (총90포) '}
# 2020-07-02 04:47:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1781618194&ver=637292944591264582>
# {'discount_rate': '2.57%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1781618194&ver=637292944591264582',
#  'o_price': '31900',
#  's_price': '31080',
#  'title': '[폴로랄프로렌] 폴로랄프로렌 남녀공용 베이직로고 반팔티셔츠 '}
# 2020-07-02 04:47:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1811563066&ver=637292944591264582>
# {'discount_rate': '6.97%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1811563066&ver=637292944591264582',
#  'o_price': '109000',
#  's_price': '101400',
#  'title': '[리복] 리복 에어리라이트 브라팬티 5세트+볼륨패드2개+트레이닝 숏팬츠2종 '}
# 2020-07-02 04:47:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1649456622&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1649456622&ver=637292944591264582>
# {'discount_rate': '69.98%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1649456622&ver=637292944591264582',
#  'o_price': '66300',
#  's_price': '19900',
#  'title': '[올리비아로렌] 여름 판매 BEST + 역시즌 아이템  최대 25% 쿠폰 '}
# 2020-07-02 04:47:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1822327700&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1822327700&ver=637292944591264582>
# {'discount_rate': '13.48%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1822327700&ver=637292944591264582',
#  'o_price': '23000',
#  's_price': '19900',
#  'title': '[엘르이너웨어] 여름엔 스킨 브라팬티 6종택1 EPB16052EPH16052-6 '}
# 2020-07-02 04:47:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1817237042&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1817237042&ver=637292944591264582>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1817237042&ver=637292944591264582',
#  'o_price': '33000',
#  's_price': '9900',
#  'title': '루즈델리 빅세일20% 롱원피스/빅사이즈/린넨/티 '}
# 2020-07-02 04:47:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1822656897&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1833296816&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1822934262&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1822656897&ver=637292944591264582>
# {'discount_rate': '17.38%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1822656897&ver=637292944591264582',
#  'o_price': '20540',
#  's_price': '16970',
#  'title': '[켈로그] 첵스초코 3종(쿠키앤크림+스노우+마시멜로) '}
# 2020-07-02 04:47:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1833296816&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1833296816&ver=637292944591264582',
#  'o_price': '26900',
#  's_price': '26900',
#  'title': '국내생산) 어썸케어 3중필터 덴탈마스크 50매/일회용 '}
# 2020-07-02 04:47:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1822934262&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1822934262&ver=637292944591264582',
#  'o_price': '16900',
#  's_price': '16900',
#  'title': '[고려은단] 마시는 고려은단 비타민C 1000 100ml 10입X5박스 '}
# 2020-07-02 04:47:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=585842847&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=585842847&ver=637292944591264582>
# {'discount_rate': '69.36%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=585842847&ver=637292944591264582',
#  'o_price': '40800',
#  's_price': '12500',
#  'title': '[메이블린] 메이블린 뉴욕 슈퍼 스테이 핑크/핏미 외 특가 '}
# 2020-07-02 04:47:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1833843067&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1833843067&ver=637292944591264582>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1833843067&ver=637292944591264582',
#  'o_price': '24000',
#  's_price': '24000',
#  'title': '[리바이스바디웨어] 현대아울렛 리바이스 남녀 언더/이지웨어 득템가 '}
# 2020-07-02 04:47:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1267464808&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1678643774&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1267464808&ver=637292944591264582>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1267464808&ver=637292944591264582',
#  'o_price': '28000',
#  's_price': '14000',
#  'title': '[게스] 빅세일20%+7%게스 본사 수지s PICK FLEX '}
# 2020-07-02 04:47:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1678643774&ver=637292944591264582>
# {'discount_rate': '64.72%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1678643774&ver=637292944591264582',
#  'o_price': '30900',
#  's_price': '10900',
#  'title': '[롬앤] ~64%off 롬앤 신상립 30종 선런칭/일부품목1+1 '}
# 2020-07-02 04:47:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1287247888&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1790000271&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:51 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1287247888&ver=637292944591264582>
# {'discount_rate': '37.14%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1287247888&ver=637292944591264582',
#  'o_price': '15750',
#  's_price': '9900',
#  'title': '[너트리] 캘리포니아 볶음아몬드 500g x 2개 19년산 '}
# 2020-07-02 04:47:51 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1790000271&ver=637292944591108578>
# {'discount_rate': '14.57%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1790000271&ver=637292944591108578',
#  'o_price': '34180',
#  's_price': '29200',
#  'title': '[삼성물산] 삼성 프리미엄 그린 A4 복사용지 A4용지 75g 2BOX '}
# 2020-07-02 04:47:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=971074017&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:51 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=971074017&ver=637292944591108578>
# {'discount_rate': '15.67%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=971074017&ver=637292944591108578',
#  'o_price': '31900',
#  's_price': '26900',
#  'title': '[잘풀리는집] 잘풀리는집 순수 프리미엄 30mx30롤 2팩/화장지 '}
# 2020-07-02 04:47:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1798281354&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1714457661&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:51 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1798281354&ver=637292944591108578>
# {'discount_rate': '53.03%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1798281354&ver=637292944591108578',
#  'o_price': '33000',
#  's_price': '15500',
#  'title': '[뉴트리디데이] 디카페 다이어트 다크 아메리카노맛 1박스 (90포) '}
# 2020-07-02 04:47:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1714457661&ver=637292944591108578>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1714457661&ver=637292944591108578',
#  'o_price': '78000',
#  's_price': '39000',
#  'title': '[미샤] 미샤 상반기 결산 인기상품 1+1 외 BEST50 전품목 30% '}
# 2020-07-02 04:47:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1827907353&ver=637292944591264582> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1596507004&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1827907353&ver=637292944591264582>
# {'discount_rate': '63.67%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1827907353&ver=637292944591264582',
#  'o_price': '30000',
#  's_price': '10900',
#  'title': '[소다스쿨] 과탄산소다 특대용량 7kg  / 산소계 표백제 '}
# 2020-07-02 04:47:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1596507004&ver=637292944591108578>
# {'discount_rate': '69.97%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1596507004&ver=637292944591108578',
#  'o_price': '59600',
#  's_price': '17900',
#  'title': '[키스해링] 20SS 기획 특집 팝아트 드로즈 5종 패키지 OKMD0S '}
# 2020-07-02 04:47:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1834221128&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1834221128&ver=637292944591108578>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1834221128&ver=637292944591108578',
#  'o_price': '11900',
#  's_price': '11900',
#  'title': '털 복숭아  1.8kg내외(8과내외)/2개구매시4.5kg발송 '}
# 2020-07-02 04:47:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1776041173&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1776041173&ver=637292944591108578>
# {'discount_rate': '59.31%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1776041173&ver=637292944591108578',
#  'o_price': '29000',
#  's_price': '11800',
#  'title': '[랩] 랩 균일가 인기 티셔츠/원피스 균일가 32종 특가찬스 '}
# 2020-07-02 04:47:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=627247117&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=627247117&ver=637292944591108578>
# {'discount_rate': '69.9%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=627247117&ver=637292944591108578',
#  'o_price': '19600',
#  's_price': '5900',
#  'title': '더다다 여름신상 빅사이즈 롱티셔츠/셔츠/원피스 '}
# 2020-07-02 04:47:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1107177865&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=133298006&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=670624522&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1107177865&ver=637292944591108578>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1107177865&ver=637292944591108578',
#  'o_price': '50000',
#  's_price': '15000',
#  'title': '[바닐라코] 바닐라코 여름세일이 왔수박 upto60%/1+1/2+1까지 '}
# 2020-07-02 04:47:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=133298006&ver=637292944591108578>
# {'discount_rate': '55.71%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=133298006&ver=637292944591108578',
#  'o_price': '35000',
#  's_price': '15500',
#  'title': '[아디다스] 아디다스 나이키外 바캉스 슬리퍼/실내화/샌들 모음 '}
# 2020-07-02 04:47:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=670624522&ver=637292944591108578>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=670624522&ver=637292944591108578',
#  'o_price': '33000',
#  's_price': '9900',
#  'title': '[매니몰] (빅세일20%) 반팔티/티셔츠/남자/여자/ 캠핑 S~4XL '}
# 2020-07-02 04:47:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1570676515&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1570676515&ver=637292944591108578>
# {'discount_rate': '33.33%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1570676515&ver=637292944591108578',
#  'o_price': '29850',
#  's_price': '19900',
#  'title': '[훈훈] 블랙타이거새우 500g 1팩 10미 '}
# 2020-07-02 04:47:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1101169778&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1802018139&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1101169778&ver=637292944591108578>
# {'discount_rate': '30.12%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1101169778&ver=637292944591108578',
#  'o_price': '49800',
#  's_price': '34800',
#  'title': '[맥심] 맥심 모카골드 커피믹스 320T +썸머 비치타월 증정 '}
# 2020-07-02 04:47:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1802018139&ver=637292944591108578>
# {'discount_rate': '20.2%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1802018139&ver=637292944591108578',
#  'o_price': '30000',
#  's_price': '23940',
#  'title': '[레노마셔츠] (신세계센텀점)2020년 가성비좋은 시원한 여름 반팔셔츠 20종 중 택1 (RKUSL1111) '}
# 2020-07-02 04:47:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1829759718&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1829759718&ver=637292944591108578>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1829759718&ver=637292944591108578',
#  'o_price': '25000',
#  's_price': '25000',
#  'title': '[라네즈] 네오 쿠션 매트 15G/24시간모공커버/쿠션팩트/컨실러급 '}
# 2020-07-02 04:47:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1510254627&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=858294811&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1510254627&ver=637292944591108578>
# {'discount_rate': '40.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1510254627&ver=637292944591108578',
#  'o_price': '21500',
#  's_price': '12900',
#  'title': '[코코팜] 코코팜 화이트요구르트 340mlx24캔 '}
# 2020-07-02 04:47:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=858294811&ver=637292944591108578>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=858294811&ver=637292944591108578',
#  'o_price': '89400',
#  's_price': '44700',
#  'title': '황금미가 쌀 20kg 19년산 (당일도정) '}
# 2020-07-02 04:47:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1821531249&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1821531249&ver=637292944591108578>
# {'discount_rate': '5.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1821531249&ver=637292944591108578',
#  'o_price': '39000',
#  's_price': '37050',
#  'title': '[마모트] (NO 세일) 마모트 20SS 썸머 하트라인핏 레깅스 5종세트(레깅스3+티셔츠1+반바지1) '}
# 2020-07-02 04:47:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1101182286&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:54 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1101182286&ver=637292944591108578>
# {'discount_rate': '30.02%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1101182286&ver=637292944591108578',
#  'o_price': '61300',
#  's_price': '42900',
#  'title': '[맥심] 맥심 모카골드 커피믹스 400T +아이스 콜드컵 증정 '}
# 2020-07-02 04:47:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=625785863&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:47:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=625785863&ver=637292944591108578>
# {'discount_rate': '69.74%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=625785863&ver=637292944591108578',
#  'o_price': '38000',
#  's_price': '11500',
#  'title': '[데일리앤] 여름신상 플라워 쉬폰 뷔스티에 데님 롱 원피스 '}
# ...
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1728087311&ver=637292944591108578',
#  'o_price': '40000',
#  's_price': '20000',
#  'title': '[에뛰드하우스] Beauty BIG SALE 30~50% + 중복쿠폰발급 '}
# 2020-07-02 04:48:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=651979588&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=651979588&ver=637292944591108578>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=651979588&ver=637292944591108578',
#  'o_price': '26000',
#  's_price': '7800',
#  'title': '[데일리앤] 데일리앤 여름신상/반팔티/브이넥/레터링/롱티셔츠 '}
# 2020-07-02 04:48:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1305842596&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1679402654&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1305842596&ver=637292944591108578>
# {'discount_rate': '69.7%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1305842596&ver=637292944591108578',
#  'o_price': '33000',
#  's_price': '10000',
#  'title': '[지오다노] 지오다노 시즌오프+빅세일 반팔/반바지/치노 최대특가 '}
# 2020-07-02 04:48:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1309233372&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1679402654&ver=637292944591108578>
# {'discount_rate': '62.92%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1679402654&ver=637292944591108578',
#  'o_price': '24000',
#  's_price': '8900',
#  'title': '[페리오] 치약 뉴후레쉬알파치약 170g x 10개 국민치약 '}
# 2020-07-02 04:48:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1309233372&ver=637292944591108578>
# {'discount_rate': '69.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1309233372&ver=637292944591108578',
#  'o_price': '26300',
#  's_price': '7900',
#  'title': '프라이데이 20% 빅세일 5900~ 빅사이즈/롱티/박스 '}
# 2020-07-02 04:48:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1722135077&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:12 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1722135077&ver=637292944591108578>
# {'discount_rate': '69.98%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1722135077&ver=637292944591108578',
#  'o_price': '41300',
#  's_price': '12400',
#  'title': '스타스텝 20%쿠폰 빅사이즈/원피스/티셔츠/세트 '}
# 2020-07-02 04:48:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1788177969&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:12 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1788177969&ver=637292944591108578>
# {'discount_rate': '8.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1788177969&ver=637292944591108578',
#  'o_price': '28000',
#  's_price': '25760',
#  'title': '루이까또즈 햇빛차단 백화점상품 양산특가 '}
# 2020-07-02 04:48:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1815818997&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:12 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1815818997&ver=637292944591108578>
# {'discount_rate': '20.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1815818997&ver=637292944591108578',
#  'o_price': '79900',
#  's_price': '63920',
#  'title': '20 S/S 데싱디바 페디 슈퍼슬림핏 오캘리포니아 컬렉션 '}
# 2020-07-02 04:48:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1503128123&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=929105077&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:12 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1503128123&ver=637292944591108578>
# {'discount_rate': '40.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1503128123&ver=637292944591108578',
#  'o_price': '21500',
#  's_price': '12900',
#  'title': '[코코팜] 코코팜 피치핑크 340mlx24캔 '}
# 2020-07-02 04:48:12 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=929105077&ver=637292944591108578>
# {'discount_rate': '69.9%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=929105077&ver=637292944591108578',
#  'o_price': '19600',
#  's_price': '5900',
#  'title': '3+1 여름 쿨링팬츠/카고바지/와이드/빅사이즈+20%쿠폰 '}
# 2020-07-02 04:48:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1834219389&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=861577112&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1834219389&ver=637292944591108578>
# {'discount_rate': '37.54%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1834219389&ver=637292944591108578',
#  'o_price': '14250',
#  's_price': '8900',
#  'title': '털 복숭아  1.8kg내외(10과내외)/2개구매시4.5kg발송 '}
# 2020-07-02 04:48:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1285565414&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1516427212&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=861577112&ver=637292944591108578>
# {'discount_rate': '69.93%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=861577112&ver=637292944591108578',
#  'o_price': '29600',
#  's_price': '8900',
#  'title': '[이사도라] 여름 신상 뮬슬리퍼 젤리슈즈 뮬스니커즈 '}
# 2020-07-02 04:48:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1285565414&ver=637292944591108578>
# {'discount_rate': '7.52%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1285565414&ver=637292944591108578',
#  'o_price': '6380',
#  's_price': '5900',
#  'title': '콩나물 재배기 + 국산콩증정 '}
# 2020-07-02 04:48:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1516427212&ver=637292944591108578>
# {'discount_rate': '15.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1516427212&ver=637292944591108578',
#  'o_price': '10000',
#  's_price': '8500',
#  'title': '[2080] 2080 어린이치약 키즈크리닉 순한민트 80gx5개 '}
# 2020-07-02 04:48:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1787960274&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=751249829&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1787960274&ver=637292944591108578>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1787960274&ver=637292944591108578',
#  'o_price': '46000',
#  's_price': '13800',
#  'title': '브리치x한미미 20%+7%쿠폰 티셔츠/블라우스/원피스 '}
# 2020-07-02 04:48:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=751249829&ver=637292944591108578>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=751249829&ver=637292944591108578',
#  'o_price': '23000',
#  's_price': '6900',
#  'title': '쏭스타일 롱티.루즈핏.박스티.신상특가 '}
# 2020-07-02 04:48:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1820926820&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1542123698&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1820926820&ver=637292944591108578>
# {'discount_rate': '9.17%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1820926820&ver=637292944591108578',
#  'o_price': '10900',
#  's_price': '9900',
#  'title': '국내 인증 일회용마스크 50매 화이트 멜트블로운 필터 '}
# 2020-07-02 04:48:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1542123698&ver=637292944591108578>
# {'discount_rate': '40.09%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1542123698&ver=637292944591108578',
#  'o_price': '23200',
#  's_price': '13900',
#  'title': '[헛개컨디션] CJ 컨디션헛개 75ml x 10병 / 컨디션헛개수 숙취음료 '}
# 2020-07-02 04:48:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1620413379&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1685460952&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1583097834&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1620413379&ver=637292944591108578>
# {'discount_rate': '35.64%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1620413379&ver=637292944591108578',
#  'o_price': '43350',
#  's_price': '27900',
#  'title': '키위 제스프리 골드 키위 특대과 30과 '}
# 2020-07-02 04:48:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1685460952&ver=637292944591108578>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1685460952&ver=637292944591108578',
#  'o_price': '33500',
#  's_price': '33500',
#  'title': '모다아울렛 타미힐피거 반팔카라티 최대할인전 '}
# 2020-07-02 04:48:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1583097834&ver=637292944591108578>
# {'discount_rate': '69.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1583097834&ver=637292944591108578',
#  'o_price': '49600',
#  's_price': '14900',
#  'title': '브리치x아이미마인 20%+7%쿠폰 반팔/블라우스/원피스 '}
# 2020-07-02 04:48:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1345149344&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1345149344&ver=637292944591108578>
# {'discount_rate': '69.98%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1345149344&ver=637292944591108578',
#  'o_price': '46300',
#  's_price': '13900',
#  'title': '브리치x럭키567 20%+7%쿠폰 반팔/블라우스/원피스 '}
# 2020-07-02 04:48:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=635067641&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1830306098&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1836050674&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=635067641&ver=637292944591108578>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=635067641&ver=637292944591108578',
#  'o_price': '56000',
#  's_price': '16800',
#  'title': '[난닝구] 20%쿠폰 난닝구 여름SALE 티셔츠/원피스 (5만무배) '}
# 2020-07-02 04:48:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1830306098&ver=637292944591108578>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1830306098&ver=637292944591108578',
#  'o_price': '36900',
#  's_price': '36900',
#  'title': '동아 전과 / 백점 국과사/ 백점 전과목 세트 2학기 선택구매 (1-2. 2-2. 3-2. 4-2. 5-2. 6-2) '}
# 2020-07-02 04:48:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1836050674&ver=637292944591108578>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1836050674&ver=637292944591108578',
#  'o_price': '27800',
#  's_price': '25020',
#  'title': '국내생산 FDA 승인 귀가 편한 3중필터 마스크 50매 '}
# 2020-07-02 04:48:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=767588368&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:15 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=767588368&ver=637292944591108578>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=767588368&ver=637292944591108578',
#  'o_price': '33000',
#  's_price': '9900',
#  'title': '14K귀걸이(Gold-Pin) 외 로즈골드 쥬얼리 특가전 '}
# 2020-07-02 04:48:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1792465372&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1836263711&ver=637292944591108578> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 04:48:15 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1792465372&ver=637292944591108578>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1792465372&ver=637292944591108578',
#  'o_price': '21900',
#  's_price': '21900',
#  'title': '[ahc] AHC 더퓨어 아이크림 30ml 4개 + 3종 키트 증정 '}
# 2020-07-02 04:48:15 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1836263711&ver=637292944591108578>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1836263711&ver=637292944591108578',
#  'o_price': '25000',
#  's_price': '22500',
#  'title': '[아이더] (현대백화점)아이더 남성 트위스팅 폴로 티셔츠 '}
# 2020-07-02 04:48:15 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-07-02 04:48:15 [scrapy.extensions.feedexport] INFO: Stored csv feed (199 items) in: GmarketBestsellers.csv
# 2020-07-02 04:48:15 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 75169,
#  'downloader/request_count': 203,
#  'downloader/request_method_count/GET': 203,
#  'downloader/response_bytes': 7599110,
#  'downloader/response_count': 203,
#  'downloader/response_status_count/200': 203,
#  'elapsed_time_seconds': 36.420635,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 7, 2, 4, 48, 15, 396833),
#  'item_scraped_count': 199,
#  'log_count/DEBUG': 405,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 11,
#  'memusage/max': 55697408,
#  'memusage/startup': 55697408,
#  'request_depth_max': 1,
#  'response_received_count': 203,
#  'robotstxt/request_count': 2,
#  'robotstxt/response_count': 2,
#  'robotstxt/response_status_count/200': 2,
#  'scheduler/dequeued': 201,
#  'scheduler/dequeued/memory': 201,
#  'scheduler/enqueued': 201,
#  'scheduler/enqueued/memory': 201,
#  'spider_exceptions/ValueError': 1,
#  'start_time': datetime.datetime(2020, 7, 2, 4, 47, 38, 976198)}
# 2020-07-02 04:48:15 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# !ls crawler/
# Out:
# GmarketBestsellers.csv	crawler  scrapy.cfg

# %%
# !pwd
# Out:
# /home/ubuntu/python3/notebook/crawler

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/ubuntu/python3/notebook/crawler'

# %%
os.chdir('/home/ubuntu/python3/notebook')

# %%
files = !ls crawler/
files
# Out:
# ['GmarketBestsellers.csv', 'crawler', 'scrapy.cfg']

# %%
df = pd.read_csv(files[0])
df.tail(2)
# Out:
#     discount_rate                                               link  o_price  \
# 197          0.0%  http://item.gmarket.co.kr/Item?goodscode=17924...    21900
# 198         10.0%  http://item.gmarket.co.kr/Item?goodscode=18362...    25000
#
#      s_price                                   title
# 197    21900  [ahc] AHC 더퓨어 아이크림 30ml 4개 + 3종 키트 증정
# 198    22500        [아이더] (현대백화점)아이더 남성 트위스팅 폴로 티셔츠

# %% [markdown]
# #### 5. Pipelines 설정
# - item을 출력하기 전에 실행되는 코드를 정의

# %%
import requests
import json

def send_slack(msg):
    WEBHOOK_URL = "https://hooks.slack.com/services/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"
    payload = {
        "channel": "#welcome",
        "username": "NYM",
        "text": msg,
    }
    requests.post(WEBHOOK_URL, json.dumps(payload))

# %%
send_slack("테스트")

# %%
# !cat ~/python3/notebook/crawler/crawler/pipelines.py
# Out:
# # Define your item pipelines here
# #
# # Don't forget to add your pipeline to the ITEM_PIPELINES setting
# # See: https://docs.scrapy.org/en/latest/topics/item-pipeline.html
#
#
# # useful for handling different item types with a single interface
# from itemadapter import ItemAdapter
#
#
# class CrawlerPipeline:
#     def process_item(self, item, spider):
#         return item

# %%
# %%writefile crawler/crawler/pipelines.py
import requests
import json

class CrawlerPipeline(object):
    
    def __send_slack(self, msg):
        WEBHOOK_URL = "https://hooks.slack.com/services/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"
        payload = {
            "channel": "#welcome",
            "username": "NYM",
            "text": msg,
        }
        requests.post(WEBHOOK_URL, json.dumps(payload))
        
    def process_item(self, item, spider):
        keyword = "세트"
        print("="*100)
        print(item["title"], keyword)
        print("="*100)
        if keyword in item["title"]:
            self.__send_slack("{},{},{}".format(
                item["title"], item["s_price"], item["link"]))
        return item
# Out:
# Overwriting crawler/crawler/pipelines.py

# %% [markdown]
# - pipeline 설정 : settings.py
# ```
# ITEM_PIPELINES = {
#     'crawler.pipelines.CrawlerPipeline': 300,
# }
# ```

# %%
# echo 뒤에 오는 문자열을 출력, > 하나면 지우고 추가, >> 밑에 추가

# %%
# !echo "ITEM_PIPELINES = {" >> crawler/crawler/settings.py
# !echo "  'crawler.pipelines.CrawlerPipeline': 300," >> crawler/crawler/settings.py
# !echo "}" >> crawler/crawler/settings.py

# %%
# !tail -n 3 crawler/crawler/settings.py
# Out:
# ITEM_PIPELINES = {
#   'crawler.pipelines.CrawlerPipeline': 300,
# }

# %%
# !./run.sh
# Out:
# 2020-07-02 05:58:29 [scrapy.utils.log] INFO: Scrapy 2.2.0 started (bot: crawler)
# 2020-07-02 05:58:29 [scrapy.utils.log] INFO: Versions: lxml 4.5.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.6.9 (default, Apr 15 2020, 12:56:52) - [GCC 7.5.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.9.2, Platform Linux-5.3.0-1023-aws-x86_64-with-debian-buster-sid
# 2020-07-02 05:58:29 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-07-02 05:58:29 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawler',
#  'NEWSPIDER_MODULE': 'crawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['crawler.spiders']}
# 2020-07-02 05:58:29 [scrapy.extensions.telnet] INFO: Telnet Password: 2c5401cfacb1a5a0
# 2020-07-02 05:58:29 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-07-02 05:58:29 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-07-02 05:58:29 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-07-02 05:58:30 [scrapy.middleware] INFO: Enabled item pipelines:
# ['crawler.pipelines.CrawlerPipeline']
# 2020-07-02 05:58:30 [scrapy.core.engine] INFO: Spider opened
# 2020-07-02 05:58:30 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-07-02 05:58:30 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-07-02 05:58:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://corners.gmarket.co.kr/robots.txt> (referer: None)
# 2020-07-02 05:58:30 [protego] DEBUG: Rule at line 3 without any user agent to enforce it on.
# 2020-07-02 05:58:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://corners.gmarket.co.kr/Bestsellers> (referer: None)
# 2020-07-02 05:58:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/robots.txt> (referer: None)
# 2020-07-02 05:58:30 [protego] DEBUG: Rule at line 1 without any user agent to enforce it on.
# 2020-07-02 05:58:30 [protego] DEBUG: Rule at line 2 without any user agent to enforce it on.
# 2020-07-02 05:58:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1759999008&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=495818668&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [동원참치] 동원 펭수참치 135g6 + 동원참치135g6  세트
# ====================================================================================================
# 2020-07-02 05:58:31 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1759999008&ver=637292987102187149>
# {'discount_rate': '18.26%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1759999008&ver=637292987102187149',
#  'o_price': '21900',
#  's_price': '17900',
#  'title': '[동원참치] 동원 펭수참치 135g6 + 동원참치135g6 '}
# 2020-07-02 05:58:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1493559466&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [젤리스푼] 아동복/아동의류/여아원피스/상하복/실내복/여름옷  세트
# ====================================================================================================
# 2020-07-02 05:58:31 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=495818668&ver=637292987102187149>
# {'discount_rate': '69.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=495818668&ver=637292987102187149',
#  'o_price': '26300',
#  's_price': '7900',
#  'title': '[젤리스푼] 아동복/아동의류/여아원피스/상하복/실내복/여름옷 '}
# ====================================================================================================
# [SOUP] SOUP外 균일 16900원 썸머 원피스/블라우스/티셔츠  세트
# ====================================================================================================
# 2020-07-02 05:58:31 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1493559466&ver=637292987102187149>
# {'discount_rate': '50.29%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1493559466&ver=637292987102187149',
#  'o_price': '34000',
#  's_price': '16900',
#  'title': '[SOUP] SOUP外 균일 16900원 썸머 원피스/블라우스/티셔츠 '}
# 2020-07-02 05:58:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1291296753&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=876722053&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 햇마루 돈편육 250g X 4팩  세트
# ====================================================================================================
# 2020-07-02 05:58:31 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1291296753&ver=637292987102187149>
# {'discount_rate': '30.28%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1291296753&ver=637292987102187149',
#  'o_price': '14200',
#  's_price': '9900',
#  'title': '햇마루 돈편육 250g X 4팩 '}
# ====================================================================================================
# 무염볶음 캐슈넛 400g+400g 견과류 2020년산  세트
# ====================================================================================================
# 2020-07-02 05:58:31 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=876722053&ver=637292987102187149>
# {'discount_rate': '38.5%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=876722053&ver=637292987102187149',
#  'o_price': '19350',
#  's_price': '11900',
#  'title': '무염볶음 캐슈넛 400g+400g 견과류 2020년산 '}
# 2020-07-02 05:58:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1806345360&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [아이더] 갤러리아   2020년 출시제품  엘리 남성 폴로 티셔츠 DMM20281  세트
# ====================================================================================================
# 2020-07-02 05:58:32 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1806345360&ver=637292987102187149>
# {'discount_rate': '14.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1806345360&ver=637292987102187149',
#  'o_price': '34000',
#  's_price': '29240',
#  'title': '[아이더] 갤러리아   2020년 출시제품  엘리 남성 폴로 티셔츠 DMM20281 '}
# 2020-07-02 05:58:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1503128123&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [코코팜] 코코팜 피치핑크 340mlx24캔  세트
# ====================================================================================================
# 2020-07-02 05:58:32 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1503128123&ver=637292987102187149>
# {'discount_rate': '40.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1503128123&ver=637292987102187149',
#  'o_price': '21500',
#  's_price': '12900',
#  'title': '[코코팜] 코코팜 피치핑크 340mlx24캔 '}
# 2020-07-02 05:58:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1788177969&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 루이까또즈 햇빛차단 백화점상품 양산특가  세트
# ====================================================================================================
# 2020-07-02 05:58:32 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1788177969&ver=637292987102187149>
# {'discount_rate': '8.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1788177969&ver=637292987102187149',
#  'o_price': '28000',
#  's_price': '25760',
#  'title': '루이까또즈 햇빛차단 백화점상품 양산특가 '}
# 2020-07-02 05:58:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1373677338&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1309233372&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1784366137&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [웨스트우드] 웨스트우드 썸머시즌 티셔츠/팬츠/조끼 베스트전  세트
# ====================================================================================================
# 2020-07-02 05:58:32 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1373677338&ver=637292987102187149>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1373677338&ver=637292987102187149',
#  'o_price': '20000',
#  's_price': '10000',
#  'title': '[웨스트우드] 웨스트우드 썸머시즌 티셔츠/팬츠/조끼 베스트전 '}
# ====================================================================================================
# 프라이데이 20% 빅세일 5900~ 빅사이즈/롱티/박스  세트
# ====================================================================================================
# 2020-07-02 05:58:32 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1309233372&ver=637292987102187149>
# {'discount_rate': '69.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1309233372&ver=637292987102187149',
#  'o_price': '26300',
#  's_price': '7900',
#  'title': '프라이데이 20% 빅세일 5900~ 빅사이즈/롱티/박스 '}
# ====================================================================================================
# [안다르] 패션빅세일 여름안다르 특가2  세트
# ====================================================================================================
# 2020-07-02 05:58:32 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1784366137&ver=637292987102187149>
# {'discount_rate': '33.33%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1784366137&ver=637292987102187149',
#  'o_price': '39000',
#  's_price': '26000',
#  'title': '[안다르] 패션빅세일 여름안다르 특가2 '}
# 2020-07-02 05:58:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1620413379&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 키위 제스프리 골드 키위 특대과 30과  세트
# ====================================================================================================
# 2020-07-02 05:58:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1620413379&ver=637292987102187149>
# {'discount_rate': '35.64%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1620413379&ver=637292987102187149',
#  'o_price': '43350',
#  's_price': '27900',
#  'title': '키위 제스프리 골드 키위 특대과 30과 '}
# 2020-07-02 05:58:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1834348301&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [네파] 네파 여성 역시즌 몬테 롱 다운 7F82049  세트
# ====================================================================================================
# 2020-07-02 05:58:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1834348301&ver=637292987102187149>
# {'discount_rate': '23.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1834348301&ver=637292987102187149',
#  'o_price': '189000',
#  's_price': '145530',
#  'title': '[네파] 네파 여성 역시즌 몬테 롱 다운 7F82049 '}
# 2020-07-02 05:58:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1685611499&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1785046409&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1791565626&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 프레시지 삼시세끼 스테이크 (2인) 밀키트 쿠킹박스  세트
# ====================================================================================================
# 2020-07-02 05:58:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1685611499&ver=637292987102187149>
# {'discount_rate': '30.09%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1685611499&ver=637292987102187149',
#  'o_price': '11300',
#  's_price': '7900',
#  'title': '프레시지 삼시세끼 스테이크 (2인) 밀키트 쿠킹박스 '}
# ====================================================================================================
# [마미포코] 땀먹는 팬티 기저귀 /특대 남아 32매 6팩+자동차타워  세트
# ====================================================================================================
# 2020-07-02 05:58:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1785046409&ver=637292987102187149>
# {'discount_rate': '35.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1785046409&ver=637292987102187149',
#  'o_price': '117700',
#  's_price': '76500',
#  'title': '[마미포코] 땀먹는 팬티 기저귀 /특대 남아 32매 6팩+자동차타워 '}
# 2020-07-02 05:58:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1626678415&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [에그머니] (카드가능)(에그머니) 온라인 게임상품권 5만원  세트
# ====================================================================================================
# 2020-07-02 05:58:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1791565626&ver=637292987102187149>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1791565626&ver=637292987102187149',
#  'o_price': '50000',
#  's_price': '45000',
#  'title': '[에그머니] (카드가능)(에그머니) 온라인 게임상품권 5만원 '}
# ====================================================================================================
# [케이엠모터스] 3단 트윈 차량용 선풍기/카팬 장착키트 사은품 증정  세트
# ====================================================================================================
# 2020-07-02 05:58:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1626678415&ver=637292987102187149>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1626678415&ver=637292987102187149',
#  'o_price': '33600',
#  's_price': '16800',
#  'title': '[케이엠모터스] 3단 트윈 차량용 선풍기/카팬 장착키트 사은품 증정 '}
# 2020-07-02 05:58:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1666944408&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [파스퇴르우유] 무항생제 바른목장 우유 190ml/24팩 /유통기한 8.11  세트
# ====================================================================================================
# 2020-07-02 05:58:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1666944408&ver=637292987102187149>
# {'discount_rate': '31.75%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1666944408&ver=637292987102187149',
#  'o_price': '18900',
#  's_price': '12900',
#  'title': '[파스퇴르우유] 무항생제 바른목장 우유 190ml/24팩 /유통기한 8.11 '}
# 2020-07-02 05:58:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1833200917&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1107177865&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [디스커버리] (신세계경기점) 19F/W  디스커버리 역시즌 키즈 레스터 G 벤치 롱 구스다운자켓 DKDJ54961  세트
# ====================================================================================================
# 2020-07-02 05:58:34 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1833200917&ver=637292987102187149>
# {'discount_rate': '20.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1833200917&ver=637292987102187149',
#  'o_price': '129500',
#  's_price': '103600',
#  'title': '[디스커버리] (신세계경기점) 19F/W  디스커버리 역시즌 키즈 레스터 G 벤치 롱 구스다운자켓 DKDJ54961 '}
# ====================================================================================================
# [바닐라코] 바닐라코 여름세일이 왔수박 upto60%/1+1/2+1까지  세트
# ====================================================================================================
# 2020-07-02 05:58:34 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1107177865&ver=637292987102187149>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1107177865&ver=637292987102187149',
#  'o_price': '50000',
#  's_price': '15000',
#  'title': '[바닐라코] 바닐라코 여름세일이 왔수박 upto60%/1+1/2+1까지 '}
# 2020-07-02 05:58:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=625785863&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [데일리앤] 여름신상 플라워 쉬폰 뷔스티에 데님 롱 원피스  세트
# ====================================================================================================
# 2020-07-02 05:58:34 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=625785863&ver=637292987102187149>
# {'discount_rate': '69.74%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=625785863&ver=637292987102187149',
#  'o_price': '38000',
#  's_price': '11500',
#  'title': '[데일리앤] 여름신상 플라워 쉬폰 뷔스티에 데님 롱 원피스 '}
# 2020-07-02 05:58:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1246494669&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [아르페지오베이직] 빨아쓰는 굿슬립 워셔블베개/경추베개/기능성베개솜  세트
# ====================================================================================================
# 2020-07-02 05:58:34 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1246494669&ver=637292987102187149>
# {'discount_rate': '60.07%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1246494669&ver=637292987102187149',
#  'o_price': '29800',
#  's_price': '11900',
#  'title': '[아르페지오베이직] 빨아쓰는 굿슬립 워셔블베개/경추베개/기능성베개솜 '}
# 2020-07-02 05:58:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=173366583&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1267464808&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 가정식 생포기김치10Kg /총각/HACCP  세트
# ====================================================================================================
# 2020-07-02 05:58:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=173366583&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=173366583&ver=637292987102187149',
#  'o_price': '23900',
#  's_price': '23900',
#  'title': '가정식 생포기김치10Kg /총각/HACCP '}
# 2020-07-02 05:58:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1350339365&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [게스] 빅세일20%+7%게스 본사 수지s PICK FLEX  세트
# ====================================================================================================
# 2020-07-02 05:58:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1267464808&ver=637292987102187149>
# {'discount_rate': '50.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1267464808&ver=637292987102187149',
#  'o_price': '28000',
#  's_price': '14000',
#  'title': '[게스] 빅세일20%+7%게스 본사 수지s PICK FLEX '}
# ====================================================================================================
# [지오다노] 지오다노 시즌오프+빅세일 셔츠/린넨/슬랙스 최대특가  세트
# ====================================================================================================
# 2020-07-02 05:58:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1350339365&ver=637292987102187149>
# {'discount_rate': '69.88%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1350339365&ver=637292987102187149',
#  'o_price': '83000',
#  's_price': '25000',
#  'title': '[지오다노] 지오다노 시즌오프+빅세일 셔츠/린넨/슬랙스 최대특가 '}
# 2020-07-02 05:58:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1674638283&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [이디야커피] (이디야커피) 1만원권  세트
# ====================================================================================================
# 2020-07-02 05:58:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1674638283&ver=637292987102187149>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1674638283&ver=637292987102187149',
#  'o_price': '10000',
#  's_price': '9000',
#  'title': '[이디야커피] (이디야커피) 1만원권 '}
# 2020-07-02 05:58:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1725467202&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 루나샵 여름신상티셔츠 5900원~ 원피스/박스티/롱티  세트
# ====================================================================================================
# 2020-07-02 05:58:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1725467202&ver=637292987102187149>
# {'discount_rate': '69.9%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1725467202&ver=637292987102187149',
#  'o_price': '19600',
#  's_price': '5900',
#  'title': '루나샵 여름신상티셔츠 5900원~ 원피스/박스티/롱티 '}
# 2020-07-02 05:58:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1830250115&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=782096663&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [에어퀸] 미국 FDA 승인 에어퀸 나노 마스크 30매 대형 개별포장  세트
# ====================================================================================================
# 2020-07-02 05:58:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1830250115&ver=637292987102187149>
# {'discount_rate': '25.06%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1830250115&ver=637292987102187149',
#  'o_price': '39900',
#  's_price': '29900',
#  'title': '[에어퀸] 미국 FDA 승인 에어퀸 나노 마스크 30매 대형 개별포장 '}
# ====================================================================================================
# [HP] HP A4 복사용지(A4용지) 80g 2500매 2BOX/더블에이  세트
# ====================================================================================================
# 2020-07-02 05:58:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=782096663&ver=637292987102187149>
# {'discount_rate': '14.09%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=782096663&ver=637292987102187149',
#  'o_price': '36550',
#  's_price': '31400',
#  'title': '[HP] HP A4 복사용지(A4용지) 80g 2500매 2BOX/더블에이 '}
# 2020-07-02 05:58:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1834221128&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 털 복숭아  1.8kg내외(8과내외)/2개구매시4.5kg발송  세트
# ====================================================================================================
# 2020-07-02 05:58:35 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1834221128&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1834221128&ver=637292987102187149',
#  'o_price': '11900',
#  's_price': '11900',
#  'title': '털 복숭아  1.8kg내외(8과내외)/2개구매시4.5kg발송 '}
# 2020-07-02 05:58:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1776041173&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [랩] 랩 균일가 인기 티셔츠/원피스 균일가 32종 특가찬스  세트
# ====================================================================================================
# 2020-07-02 05:58:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1776041173&ver=637292987102187149>
# {'discount_rate': '59.31%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1776041173&ver=637292987102187149',
#  'o_price': '29000',
#  's_price': '11800',
#  'title': '[랩] 랩 균일가 인기 티셔츠/원피스 균일가 32종 특가찬스 '}
# 2020-07-02 05:58:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1830270736&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=854297588&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 모다아울렛  라코스테 데일리룩의 기본 로고반팔/프린팅 BEST세일  세트
# ====================================================================================================
# 2020-07-02 05:58:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1830270736&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1830270736&ver=637292987102187149',
#  'o_price': '36900',
#  's_price': '36900',
#  'title': '모다아울렛  라코스테 데일리룩의 기본 로고반팔/프린팅 BEST세일 '}
# ====================================================================================================
# [헤라] 헤라 블랙쿠션/파운데이션/선메이트 외 브랜드세일  세트
# ====================================================================================================
# 2020-07-02 05:58:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=854297588&ver=637292987102187149>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=854297588&ver=637292987102187149',
#  'o_price': '55000',
#  's_price': '49500',
#  'title': '[헤라] 헤라 블랙쿠션/파운데이션/선메이트 외 브랜드세일 '}
# 2020-07-02 05:58:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=822286652&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1585094302&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [클리오] (10%중복쿠폰) 7월 패션/뷰티 프로모션  세트
# ====================================================================================================
# 2020-07-02 05:58:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=822286652&ver=637292987102187149>
# {'discount_rate': '69.88%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=822286652&ver=637292987102187149',
#  'o_price': '33200',
#  's_price': '10000',
#  'title': '[클리오] (10%중복쿠폰) 7월 패션/뷰티 프로모션 '}
# ====================================================================================================
# [제이엠더블유] 에어젯 MS6020B 터보 항공모터 헤어 드라이기 냉풍위크  세트
# ====================================================================================================
# 2020-07-02 05:58:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1585094302&ver=637292987102187149>
# {'discount_rate': '40.52%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1585094302&ver=637292987102187149',
#  'o_price': '116000',
#  's_price': '69000',
#  'title': '[제이엠더블유] 에어젯 MS6020B 터보 항공모터 헤어 드라이기 냉풍위크 '}
# 2020-07-02 05:58:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1782907745&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [크리넥스] 수앤수 코튼클린 물티슈 베이직 캡형 72매10팩 BIZ.  세트
# ====================================================================================================
# 2020-07-02 05:58:36 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1782907745&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1782907745&ver=637292987102187149',
#  'o_price': '7400',
#  's_price': '7400',
#  'title': '[크리넥스] 수앤수 코튼클린 물티슈 베이직 캡형 72매10팩 BIZ. '}
# 2020-07-02 05:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=192173793&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1833296816&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [Chicline] 20%쿠폰특가/결혼식/하객룩/오피스/원피스/빅사이즈  세트
# ====================================================================================================
# 2020-07-02 05:58:37 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=192173793&ver=637292987102187149>
# {'discount_rate': '0.4%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=192173793&ver=637292987102187149',
#  'o_price': '50000',
#  's_price': '49800',
#  'title': '[Chicline] 20%쿠폰특가/결혼식/하객룩/오피스/원피스/빅사이즈 '}
# 2020-07-02 05:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1798281354&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1822934262&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 국내생산) 어썸케어 3중필터 덴탈마스크 50매/일회용  세트
# ====================================================================================================
# 2020-07-02 05:58:37 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1833296816&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1833296816&ver=637292987102187149',
#  'o_price': '26900',
#  's_price': '26900',
#  'title': '국내생산) 어썸케어 3중필터 덴탈마스크 50매/일회용 '}
# ====================================================================================================
# [뉴트리디데이] 디카페 다이어트 다크 아메리카노맛 1박스 (90포)  세트
# ====================================================================================================
# 2020-07-02 05:58:37 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1798281354&ver=637292987102187149>
# {'discount_rate': '53.03%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1798281354&ver=637292987102187149',
#  'o_price': '33000',
#  's_price': '15500',
#  'title': '[뉴트리디데이] 디카페 다이어트 다크 아메리카노맛 1박스 (90포) '}
# ====================================================================================================
# [고려은단] 마시는 고려은단 비타민C 1000 100ml 10입X5박스  세트
# ====================================================================================================
# 2020-07-02 05:58:37 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1822934262&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1822934262&ver=637292987102187149',
#  'o_price': '16900',
#  's_price': '16900',
#  'title': '[고려은단] 마시는 고려은단 비타민C 1000 100ml 10입X5박스 '}
# 2020-07-02 05:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1802018139&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [레노마셔츠] (신세계센텀점)2020년 가성비좋은 시원한 여름 반팔셔츠 20종 중 택1 (RKUSL1111)  세트
# ====================================================================================================
# 2020-07-02 05:58:37 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1802018139&ver=637292987102187149>
# {'discount_rate': '20.2%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1802018139&ver=637292987102187149',
#  'o_price': '30000',
#  's_price': '23940',
#  'title': '[레노마셔츠] (신세계센텀점)2020년 가성비좋은 시원한 여름 반팔셔츠 20종 중 택1 (RKUSL1111) '}
# 2020-07-02 05:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1551156300&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1829157651&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1805969711&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1836325957&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1830370347&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [아비노 베이비] 카밍 컴포트 로션 227g 3개  세트
# ====================================================================================================
# 2020-07-02 05:58:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1551156300&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1551156300&ver=637292987102187149',
#  'o_price': '29500',
#  's_price': '29500',
#  'title': '[아비노 베이비] 카밍 컴포트 로션 227g 3개 '}
# ====================================================================================================
# [고려은단] 마시는 고려은단 비타민C 1000 100mlX100병  세트
# ====================================================================================================
# 2020-07-02 05:58:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1829157651&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1829157651&ver=637292987102187149',
#  'o_price': '32900',
#  's_price': '32900',
#  'title': '[고려은단] 마시는 고려은단 비타민C 1000 100mlX100병 '}
# ====================================================================================================
# 위드블루 여성 쿨맥스 슬림 보이핏데님 팬츠 2종  세트
# ====================================================================================================
# 2020-07-02 05:58:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1805969711&ver=637292987102187149>
# {'discount_rate': '12.04%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1805969711&ver=637292987102187149',
#  'o_price': '49000',
#  's_price': '43100',
#  'title': '위드블루 여성 쿨맥스 슬림 보이핏데님 팬츠 2종 '}
# ====================================================================================================
# 조이풀 소가죽 보니 투웨이 샌들  세트
# ====================================================================================================
# 2020-07-02 05:58:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1836325957&ver=637292987102187149>
# {'discount_rate': '2.56%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1836325957&ver=637292987102187149',
#  'o_price': '39000',
#  's_price': '38000',
#  'title': '조이풀 소가죽 보니 투웨이 샌들 '}
# ====================================================================================================
# [브라운] 브라운체온계 IRT-6510 +필터21개/정품AS/당일무료배송  세트
# ====================================================================================================
# 2020-07-02 05:58:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1830370347&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1830370347&ver=637292987102187149',
#  'o_price': '86000',
#  's_price': '86000',
#  'title': '[브라운] 브라운체온계 IRT-6510 +필터21개/정품AS/당일무료배송 '}
# 2020-07-02 05:58:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1430266775&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 시크루즈/빅세일20%/원피스/SET아이템/바지/빅사이즈  세트
# ====================================================================================================
# 2020-07-02 05:58:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1430266775&ver=637292987102187149>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1430266775&ver=637292987102187149',
#  'o_price': '43000',
#  's_price': '12900',
#  'title': '시크루즈/빅세일20%/원피스/SET아이템/바지/빅사이즈 '}
# 2020-07-02 05:58:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1781618194&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1817237042&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [폴로랄프로렌] 폴로랄프로렌 남녀공용 베이직로고 반팔티셔츠  세트
# ====================================================================================================
# 2020-07-02 05:58:39 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1781618194&ver=637292987102187149>
# {'discount_rate': '2.57%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1781618194&ver=637292987102187149',
#  'o_price': '31900',
#  's_price': '31080',
#  'title': '[폴로랄프로렌] 폴로랄프로렌 남녀공용 베이직로고 반팔티셔츠 '}
# ====================================================================================================
# 루즈델리 빅세일20% 롱원피스/빅사이즈/린넨/티  세트
# ====================================================================================================
# 2020-07-02 05:58:39 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1817237042&ver=637292987102187149>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1817237042&ver=637292987102187149',
#  'o_price': '33000',
#  's_price': '9900',
#  'title': '루즈델리 빅세일20% 롱원피스/빅사이즈/린넨/티 '}
# 2020-07-02 05:58:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1678618377&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1686035302&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1678643774&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1552730555&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [페리오] 치약 뉴 후레쉬 알파치약 170g x 20개+여행용구강세트  세트
# ====================================================================================================
# 2020-07-02 05:58:39 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): hooks.slack.com:443
# 2020-07-02 05:58:39 [urllib3.connectionpool] DEBUG: https://hooks.slack.com:443 "POST /services/T016EL1V03D/B016T2YM39P/QhcFtCdbRgDHcIl0zMqUeNcT HTTP/1.1" 200 22
# 2020-07-02 05:58:39 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1678618377&ver=637292987102187149>
# {'discount_rate': '62.92%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1678618377&ver=637292987102187149',
#  'o_price': '48000',
#  's_price': '17800',
#  'title': '[페리오] 치약 뉴 후레쉬 알파치약 170g x 20개+여행용구강세트 '}
# 2020-07-02 05:58:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1570776879&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [제주삼다수] 제주삼다수 2L 12병/생수전문배송  세트
# ====================================================================================================
# 2020-07-02 05:58:39 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1686035302&ver=637292987102187149>
# {'discount_rate': '4.03%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1686035302&ver=637292987102187149',
#  'o_price': '12400',
#  's_price': '11900',
#  'title': '[제주삼다수] 제주삼다수 2L 12병/생수전문배송 '}
# ====================================================================================================
# [롬앤] ~64%off 롬앤 신상립 30종 선런칭/일부품목1+1  세트
# ====================================================================================================
# 2020-07-02 05:58:39 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1678643774&ver=637292987102187149>
# {'discount_rate': '64.72%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1678643774&ver=637292987102187149',
#  'o_price': '30900',
#  's_price': '10900',
#  'title': '[롬앤] ~64%off 롬앤 신상립 30종 선런칭/일부품목1+1 '}
# ====================================================================================================
# [마미요] 마미요 오리지널 물티슈 캡형 100매x10팩  세트
# ====================================================================================================
# 2020-07-02 05:58:39 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1552730555&ver=637292987102187149>
# {'discount_rate': '41.36%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1552730555&ver=637292987102187149',
#  'o_price': '22000',
#  's_price': '12900',
#  'title': '[마미요] 마미요 오리지널 물티슈 캡형 100매x10팩 '}
# ====================================================================================================
# [비쉬] (20%+중복20%) 단이틀 비쉬 인기상품 1+1 外  세트
# ====================================================================================================
# 2020-07-02 05:58:39 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1570776879&ver=637292987102187149>
# {'discount_rate': '25.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1570776879&ver=637292987102187149',
#  'o_price': '44000',
#  's_price': '33000',
#  'title': '[비쉬] (20%+중복20%) 단이틀 비쉬 인기상품 1+1 外 '}
# 2020-07-02 05:58:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1770546601&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=971074017&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:58:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1822671835&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# (창의력쑥쑥 홈스쿨링교구) 가성비 갑 아이템풀 종이블록 한글 동물 숫자 : 옵션선택  세트
# ====================================================================================================
# 2020-07-02 05:58:40 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1770546601&ver=637292987102187149>
# {'discount_rate': '9.2%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1770546601&ver=637292987102187149',
#  'o_price': '25000',
#  's_price': '22700',
#  'title': '(창의력쑥쑥 홈스쿨링교구) 가성비 갑 아이템풀 종이블록 한글 동물 숫자 : 옵션선택 '}
# ====================================================================================================
# [잘풀리는집] 잘풀리는집 순수 프리미엄 30mx30롤 2팩/화장지  세트
# ====================================================================================================
# 2020-07-02 05:58:40 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=971074017&ver=637292987102187149>
# {'discount_rate': '15.67%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=971074017&ver=637292987102187149',
#  'o_price': '31900',
#  's_price': '26900',
#  'title': '[잘풀리는집] 잘풀리는집 순수 프리미엄 30mx30롤 2팩/화장지 '}
# ====================================================================================================
# [버커루] 남여 청바지 10종 택1 (B195Z0132P외 9종)  세트
# ====================================================================================================
# 2020-07-02 05:58:40 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1822671835&ver=637292987102187149>
# ...
# 20%쿠폰할인 메이시스 사랑스러운 홈웨어/파자마  세트
# ====================================================================================================
# 2020-07-02 05:59:02 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1158276673&ver=637292987102187149>
# {'discount_rate': '69.9%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1158276673&ver=637292987102187149',
#  'o_price': '19600',
#  's_price': '5900',
#  'title': '20%쿠폰할인 메이시스 사랑스러운 홈웨어/파자마 '}
# 2020-07-02 05:59:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1787960274&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:59:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1542123698&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:59:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=939528083&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 브리치x한미미 20%+7%쿠폰 티셔츠/블라우스/원피스  세트
# ====================================================================================================
# 2020-07-02 05:59:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1787960274&ver=637292987102187149>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1787960274&ver=637292987102187149',
#  'o_price': '46000',
#  's_price': '13800',
#  'title': '브리치x한미미 20%+7%쿠폰 티셔츠/블라우스/원피스 '}
# ====================================================================================================
# [헛개컨디션] CJ 컨디션헛개 75ml x 10병 / 컨디션헛개수 숙취음료  세트
# ====================================================================================================
# 2020-07-02 05:59:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1542123698&ver=637292987102187149>
# {'discount_rate': '40.09%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1542123698&ver=637292987102187149',
#  'o_price': '23200',
#  's_price': '13900',
#  'title': '[헛개컨디션] CJ 컨디션헛개 75ml x 10병 / 컨디션헛개수 숙취음료 '}
# ====================================================================================================
# [한예지] 한예지 볼륨앤소프트 천연펄프 3겹  화장지 30롤 3팩  세트
# ====================================================================================================
# 2020-07-02 05:59:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=939528083&ver=637292987102187149>
# {'discount_rate': '63.5%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=939528083&ver=637292987102187149',
#  'o_price': '60000',
#  's_price': '21900',
#  'title': '[한예지] 한예지 볼륨앤소프트 천연펄프 3겹  화장지 30롤 3팩 '}
# 2020-07-02 05:59:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1516427212&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [2080] 2080 어린이치약 키즈크리닉 순한민트 80gx5개  세트
# ====================================================================================================
# 2020-07-02 05:59:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1516427212&ver=637292987102187149>
# {'discount_rate': '15.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1516427212&ver=637292987102187149',
#  'o_price': '10000',
#  's_price': '8500',
#  'title': '[2080] 2080 어린이치약 키즈크리닉 순한민트 80gx5개 '}
# 2020-07-02 05:59:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1285565414&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:59:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=861577112&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 콩나물 재배기 + 국산콩증정  세트
# ====================================================================================================
# 2020-07-02 05:59:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1285565414&ver=637292987102187149>
# {'discount_rate': '7.52%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1285565414&ver=637292987102187149',
#  'o_price': '6380',
#  's_price': '5900',
#  'title': '콩나물 재배기 + 국산콩증정 '}
# 2020-07-02 05:59:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1345149344&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [이사도라] 여름 신상 뮬슬리퍼 젤리슈즈 뮬스니커즈  세트
# ====================================================================================================
# 2020-07-02 05:59:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=861577112&ver=637292987102187149>
# {'discount_rate': '69.93%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=861577112&ver=637292987102187149',
#  'o_price': '29600',
#  's_price': '8900',
#  'title': '[이사도라] 여름 신상 뮬슬리퍼 젤리슈즈 뮬스니커즈 '}
# ====================================================================================================
# 브리치x럭키567 20%+7%쿠폰 반팔/블라우스/원피스  세트
# ====================================================================================================
# 2020-07-02 05:59:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1345149344&ver=637292987102187149>
# {'discount_rate': '69.98%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1345149344&ver=637292987102187149',
#  'o_price': '46300',
#  's_price': '13900',
#  'title': '브리치x럭키567 20%+7%쿠폰 반팔/블라우스/원피스 '}
# 2020-07-02 05:59:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1642302984&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:59:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1792465372&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:59:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1830306098&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [돌] Dole VF37 오늘맑음 100% 과채즙 야채 주스 120ml 32팩  세트
# ====================================================================================================
# 2020-07-02 05:59:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1642302984&ver=637292987102187149>
# {'discount_rate': '40.07%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1642302984&ver=637292987102187149',
#  'o_price': '28200',
#  's_price': '16900',
#  'title': '[돌] Dole VF37 오늘맑음 100% 과채즙 야채 주스 120ml 32팩 '}
# ====================================================================================================
# [ahc] AHC 더퓨어 아이크림 30ml 4개 + 3종 키트 증정  세트
# ====================================================================================================
# 2020-07-02 05:59:03 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1792465372&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1792465372&ver=637292987102187149',
#  'o_price': '21900',
#  's_price': '21900',
#  'title': '[ahc] AHC 더퓨어 아이크림 30ml 4개 + 3종 키트 증정 '}
# ====================================================================================================
# 동아 전과 / 백점 국과사/ 백점 전과목 세트 2학기 선택구매 (1-2. 2-2. 3-2. 4-2. 5-2. 6-2)  세트
# ====================================================================================================
# 2020-07-02 05:59:03 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): hooks.slack.com:443
# 2020-07-02 05:59:04 [urllib3.connectionpool] DEBUG: https://hooks.slack.com:443 "POST /services/T016EL1V03D/B016T2YM39P/QhcFtCdbRgDHcIl0zMqUeNcT HTTP/1.1" 200 22
# 2020-07-02 05:59:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1830306098&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1830306098&ver=637292987102187149',
#  'o_price': '36900',
#  's_price': '36900',
#  'title': '동아 전과 / 백점 국과사/ 백점 전과목 세트 2학기 선택구매 (1-2. 2-2. 3-2. 4-2. 5-2. 6-2) '}
# 2020-07-02 05:59:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1583097834&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:59:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1820926820&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:59:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=751249829&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:59:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1836263711&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 브리치x아이미마인 20%+7%쿠폰 반팔/블라우스/원피스  세트
# ====================================================================================================
# 2020-07-02 05:59:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1583097834&ver=637292987102187149>
# {'discount_rate': '69.96%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1583097834&ver=637292987102187149',
#  'o_price': '49600',
#  's_price': '14900',
#  'title': '브리치x아이미마인 20%+7%쿠폰 반팔/블라우스/원피스 '}
# ====================================================================================================
# 국내 인증 일회용마스크 50매 화이트 멜트블로운 필터  세트
# ====================================================================================================
# 2020-07-02 05:59:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1820926820&ver=637292987102187149>
# {'discount_rate': '9.17%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1820926820&ver=637292987102187149',
#  'o_price': '10900',
#  's_price': '9900',
#  'title': '국내 인증 일회용마스크 50매 화이트 멜트블로운 필터 '}
# ====================================================================================================
# 쏭스타일 롱티.루즈핏.박스티.신상특가  세트
# ====================================================================================================
# 2020-07-02 05:59:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=751249829&ver=637292987102187149>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=751249829&ver=637292987102187149',
#  'o_price': '23000',
#  's_price': '6900',
#  'title': '쏭스타일 롱티.루즈핏.박스티.신상특가 '}
# ====================================================================================================
# [아이더] (현대백화점)아이더 남성 트위스팅 폴로 티셔츠  세트
# ====================================================================================================
# 2020-07-02 05:59:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1836263711&ver=637292987102187149>
# {'discount_rate': '10.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1836263711&ver=637292987102187149',
#  'o_price': '25000',
#  's_price': '22500',
#  'title': '[아이더] (현대백화점)아이더 남성 트위스팅 폴로 티셔츠 '}
# 2020-07-02 05:59:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=635067641&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# 2020-07-02 05:59:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=767588368&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [난닝구] 20%쿠폰 난닝구 여름SALE 티셔츠/원피스 (5만무배)  세트
# ====================================================================================================
# 2020-07-02 05:59:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=635067641&ver=637292987102187149>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=635067641&ver=637292987102187149',
#  'o_price': '56000',
#  's_price': '16800',
#  'title': '[난닝구] 20%쿠폰 난닝구 여름SALE 티셔츠/원피스 (5만무배) '}
# ====================================================================================================
# 14K귀걸이(Gold-Pin) 외 로즈골드 쥬얼리 특가전  세트
# ====================================================================================================
# 2020-07-02 05:59:04 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=767588368&ver=637292987102187149>
# {'discount_rate': '70.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=767588368&ver=637292987102187149',
#  'o_price': '33000',
#  's_price': '9900',
#  'title': '14K귀걸이(Gold-Pin) 외 로즈골드 쥬얼리 특가전 '}
# 2020-07-02 05:59:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1685460952&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# 모다아울렛 타미힐피거 반팔카라티 최대할인전  세트
# ====================================================================================================
# 2020-07-02 05:59:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1685460952&ver=637292987102187149>
# {'discount_rate': '0.0%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1685460952&ver=637292987102187149',
#  'o_price': '33500',
#  's_price': '33500',
#  'title': '모다아울렛 타미힐피거 반팔카라티 최대할인전 '}
# 2020-07-02 05:59:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://item.gmarket.co.kr/Item?goodscode=1821541420&ver=637292987102187149> (referer: http://corners.gmarket.co.kr/Bestsellers)
# ====================================================================================================
# [스피디] 에어 벤트 차량용 10W 고속 무선충전 거치대  세트
# ====================================================================================================
# 2020-07-02 05:59:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://item.gmarket.co.kr/Item?goodscode=1821541420&ver=637292987102187149>
# {'discount_rate': '69.27%',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=1821541420&ver=637292987102187149',
#  'o_price': '17900',
#  's_price': '5500',
#  'title': '[스피디] 에어 벤트 차량용 10W 고속 무선충전 거치대 '}
# 2020-07-02 05:59:05 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-07-02 05:59:05 [scrapy.extensions.feedexport] INFO: Stored csv feed (200 items) in: GmarketBestsellers.csv
# 2020-07-02 05:59:05 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 75008,
#  'downloader/request_count': 203,
#  'downloader/request_method_count/GET': 203,
#  'downloader/response_bytes': 7441339,
#  'downloader/response_count': 203,
#  'downloader/response_status_count/200': 203,
#  'elapsed_time_seconds': 35.469697,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 7, 2, 5, 59, 5, 538441),
#  'item_scraped_count': 200,
#  'log_count/DEBUG': 426,
#  'log_count/INFO': 11,
#  'memusage/max': 59875328,
#  'memusage/startup': 59838464,
#  'request_depth_max': 1,
#  'response_received_count': 203,
#  'robotstxt/request_count': 2,
#  'robotstxt/response_count': 2,
#  'robotstxt/response_status_count/200': 2,
#  'scheduler/dequeued': 201,
#  'scheduler/dequeued/memory': 201,
#  'scheduler/enqueued': 201,
#  'scheduler/enqueued/memory': 201,
#  'start_time': datetime.datetime(2020, 7, 2, 5, 58, 30, 68744)}
# 2020-07-02 05:59:05 [scrapy.core.engine] INFO: Spider closed (finished)
