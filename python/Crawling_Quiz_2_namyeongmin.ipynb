# %% [markdown]
# ### 2. 오설록 : Scrapy
#
# - spider.py 파일에서 아래의 절차로 상품데이터를 수집하세요.
#     - 오설록 사이트의 전체상품 페이지에서 각 페이지 URL 크롤링
#         - 오설록 전체 상품 페이지 URL : https://www.osulloc.com/kr/ko/shop/item/list?category=teashop
#     - 각 상품 페이지 크롤링
#     - 상품의 상세 페이지 크롤링
#
# - 수집 데이터
#     - 상품명, 상품설명, 가격정보, 별점, 이미지링크, 상품링크
#     - title, desc, price, star, img, link
#
# - 수집된 데이터를 파이프라인을 이용하여 mongodb에 저장하세요.

# %%
import scrapy
import requests
from scrapy.http import TextResponse
from fake_useragent import UserAgent

# %%
# 프로젝트 생성

# %%
# !rm -rf osulloc/

# %%
# !scrapy startproject osulloc
# Out:
# New Scrapy project 'osulloc', using template directory 'c:\users\samsung\anaconda\lib\site-packages\scrapy\templates\project', created in:
#     C:\Users\samsung\Desktop\fastcampus\programming\programming_1\crawling exam\osulloc
#
# You can start your first spider with:
#     cd osulloc
#     scrapy genspider example example.com

# %% [markdown]
# #### 1. 아이템 모델 코드 추가

# %%
# %%writefile osulloc/osulloc/items.py


import scrapy


class OsullocItem(scrapy.Item):
    title = scrapy.Field()
    desc = scrapy.Field()
    price = scrapy.Field()
    star = scrapy.Field()
    img = scrapy.Field()
    link = scrapy.Field()
# Out:
# Overwriting osulloc/osulloc/items.py

# %%
# xpath 확인

# %%
req = requests.get("https://www.osulloc.com/kr/ko/shop/item/list?category=teashop")
response = TextResponse(req.url, body=req.text, encoding="utf-8")
response
# Out:
# <200 https://www.osulloc.com/kr/ko/shop/item/list?category=teashop>

# %%
#링크
links = response.xpath('//*[@id="contents"]/div[2]/div/div[2]/div[3]/div[1]/div/div/a/@href').extract()
links = list(map(response.urljoin, links))
links[:3]
# Out:
# ['https://www.osulloc.com/kr/ko/shop/item/teashop/1461',
#  'https://www.osulloc.com/kr/ko/shop/item/teashop/16945',
#  'https://www.osulloc.com/kr/ko/shop/item/teashop/16943']

# %%
url = links[0]
headers = { "User-Agent": UserAgent().chrome }
req = requests.get(url, headers=headers)
response = TextResponse(req.url, body=req.text, encoding="utf-8") 
response
# Out:
# <200 https://www.osulloc.com/kr/ko/shop/item/teashop/1461>

# %%
link = response.xpath('//*[@id="pagination"]/a[1]')
link
# Out:
# []

# %%
title = response.xpath('//*[@id="contents"]/div[1]/div[1]/div[2]/p[1]/text()')[0].extract()
desc = response.xpath('//*[@id="onePointArea"]/text()')[0].extract()
price = response.xpath('//*[@id="contents"]/div[1]/div[1]/div[2]/div[2]/div[2]/p/strong/text()')[0].extract()
star = response.xpath('//*[@id="contents"]/div[1]/div[2]/div/div/span/text()')[0].extract()
img = response.xpath('//*[@id="contents"]/div[1]/div[1]/div[1]/div/div[1]/img/@src').extract()

title, desc, price, star, img
# Out:
# ('러블리티박스',
#  '즐겁고 행복한 티타임을 선사하는 달콤하고 향긋한 오설록만의 특별한 블렌디드 티 선물세트 입니다.',
#  '20,000',
#  '4.6',
#  ['/upload/kr/ko/adminImage/PM/FK/20180510132548266RY.png?quality=80'])

# %% [markdown]
# #### 2. 스파이더 코드 추가

# %%
https://www.osulloc.com/kr/ko/shop/item/list?category=teashop
https://www.osulloc.com/kr/ko/shop/item/list?category=bakery

# %%
# !pip install scrapy-fake-useragent
# Out:
# Collecting scrapy-fake-useragent
#   Downloading https://files.pythonhosted.org/packages/cc/8d/faa730b8d1cb5114cb8d314b078167694d17c3d394992490551c2308928d/scrapy_fake_useragent-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: fake-useragent in c:\users\samsung\anaconda\lib\site-packages (from scrapy-fake-useragent) (0.1.11)
# Installing collected packages: scrapy-fake-useragent
# Successfully installed scrapy-fake-useragent-1.2.0

# %%
# %%writefile osulloc/osulloc/spiders/spider.py

import scrapy
from osulloc.items import OsullocItem

class OsullocSpider(scrapy.Spider):
    name = "Osulloc"
    custom_settings = {
        "DOWNLOADER_MIDDLEWARES": {
            "scrapy.downloadmiddlewares.useragent.UserAgentMiddleware": None,
            "scrapy_fake_useragent.middleware.RandomUserAgentMiddleware": 400,
        }
    }
    
    def __init__(self, category="", **kwargs):
        self.start_urls = ["https://www.osulloc.com/kr/ko/shop/item/list?category={}".format(category)]
        super().__init__(**kwargs)
        
    def start_requests(self):
        urls = ["https://www.osulloc.com/kr/ko/shop/item/list?pack=tealeaf&sort=review&category=teashop"]
        for url in urls:
            yield scrapy.Request(url, callback=self.parse)
            
    def parse(self, response):
        links = response.xpath('//*[@id="contents"]/div[2]/div/div[2]/div[3]/div[1]/div/div/a/@href').extract()
        links = list(map(lambda data:response.urljoin(data), links))
        for link in links:
            yield scrapy.Request(link, callback=self.parse_content)
            
    def parse_content(self, response):
        item = OsullocItem()
        item["title"] = response.xpath('//*[@id="contents"]/div[1]/div[1]/div[2]/p[1]/text()')[0].extract()
        item["desc"] = response.xpath('//*[@id="onePointArea"]/text()')[0].extract()
        item["price"] = response.xpath('//*[@id="contents"]/div[1]/div[1]/div[2]/div[2]/div[2]/p/strong/text()')[0].extract()
        item["star"] = response.xpath('//*[@id="contents"]/div[1]/div[2]/div/div/span/text()')[0].extract()
        item["img"] = response.xpath('//*[@id="contents"]/div[1]/div[1]/div[1]/div/div[1]/img/@src').extract()
        item["link"] = response.url
        yield item
# Out:
# Overwriting osulloc/osulloc/spiders/spider.py

# %%
# 5. 스크래피 실행시 아규먼트 설정

# %%
# teashop, bakery, themashop

# %%
# %%writefile run.sh
# cd osulloc
# scrapy crawl Osulloc -o osulloc1.csv -a category=teashop
# Out:
# Overwriting run.sh

# %%
# 실행권한 부여
# !chmod +x run.sh

# %%
! ./run.sh

# %%
df = pd.read_csv("osulloc/osulloc1.csv")
df.tail(2)
# Out:
#                          desc  \
# 22  제주 차밭의 어린 찻잎으로 만든 작설차\r\n
# 23    상쾌하고 맑은 기운을 전하는 건강차\r\n
#
#                                                   img  \
# 22  /upload/kr/ko/adminImage/DA/ZO/201909192046228...
# 23  /upload/kr/ko/adminImage/FU/NE/201910142044377...
#
#                                                  link   price  star  \
# 22  https://www.osulloc.com/kr/ko/shop/item/teasho...  40,000   4.8
# 23  https://www.osulloc.com/kr/ko/shop/item/teasho...  35,000   4.8
#
#            title
# 22    세작 80g(잎차)
# 23  도라지차 80g(잎차)

# %% [markdown]
# #### 3. 데이터 베이스 코드 추가

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb://54.180.179.245:27017/')
client
# Out:
# MongoClient(host=['54.180.179.245:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client.osulloc
collection = db.teashop
collection
# Out:
# Collection(Database(MongoClient(host=['54.180.179.245:27017'], document_class=dict, tz_aware=False, connect=True), 'osulloc'), 'teashop')

# %%
data = {"title":"teashop"}
collection.insert(data)
# Out:
# ObjectId('5f0ea7207effc4ff9392dd0a')

# %%
# %%writefile osulloc/osulloc/mongodb.py

import pymongo

client = pymongo.MongoClient('mongodb://54.180.179.245:27017/')
db = client.osulloc
collection = db.teashop
# Out:
# Overwriting osulloc/osulloc/mongodb.py

# %% [markdown]
# #### 4. 파이프라인 코드 추가

# %%
# %%writefile osulloc/osulloc/pipelines.py

from .mongodb import collection

class OsullocPipeline(object):
    
from .mongodb import collection

class OsullocPipeline(object):

    def process_item(self, item, spider):

        # mongodb에 저장
        columns = ["title", "desc", "price", "star", "img", "link"]
        data = {column: item[column] for column in columns}
        collection.insert(data)

        return item
# Out:
# Overwriting osulloc/osulloc/pipelines.py

# %%
# 파이프 라인 설정

# %%
# !echo "ITEM_PIPELINES = {" >> osulloc/osulloc/settings.py

# %%
# !echo "   'osulloc.pipelines.OsullocPipeline': 300," >> osulloc/osulloc/settings.py

# %%
# !echo "}" >> osulloc/osulloc/settings.py

# %%
# !tail -n 3 osulloc/osulloc/settings.py
# Out:
# "}"
# "   'osulloc.pipelines.OsullocPipeline': 300,"
# "}"

# %%
# 코드의 실행

# %%
# teashop, bakery, themashop

# %%
# %%writefile run.sh
# cd osulloc
# scrapy crawl Osulloc -o osulloc_teashop.csv
# Out:
# Overwriting run.sh

# %%
# !rm osulloc/*.csv

# %%
# !source run.sh
# Out:
# 2020-03-16 01:41:40 [scrapy.utils.log] INFO: Scrapy 1.6.0 started (bot: osulloc)
# 2020-03-16 01:41:40 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.1, Python 3.7.3 (default, Mar 27 2019, 16:54:48) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1  11 Sep 2018), cryptography 2.8, Platform Darwin-19.3.0-x86_64-i386-64bit
# 2020-03-16 01:41:40 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'osulloc', 'FEED_FORMAT': 'csv', 'FEED_URI': 'osulloc_teashop.csv', 'NEWSPIDER_MODULE': 'osulloc.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['osulloc.spiders']}
# 2020-03-16 01:41:40 [scrapy.extensions.telnet] INFO: Telnet Password: 0fa170f352e50849
# 2020-03-16 01:41:40 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-03-16 01:41:40 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.osulloc.com:443
# 2020-03-16 01:41:40 [urllib3.connectionpool] DEBUG: https://www.osulloc.com:443 "GET /kr/ko/shop/item/list?category=teashop HTTP/1.1" 200 None
# 2020-03-16 01:41:40 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-03-16 01:41:40 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-03-16 01:41:40 [scrapy.middleware] INFO: Enabled item pipelines:
# ['osulloc.pipelines.OsullocPipeline']
# 2020-03-16 01:41:40 [scrapy.core.engine] INFO: Spider opened
# 2020-03-16 01:41:40 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-03-16 01:41:40 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-03-16 01:41:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/robots.txt> (referer: None)
# 2020-03-16 01:41:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0> (referer: None)
# 2020-03-16 01:41:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4> (referer: None)
# 2020-03-16 01:41:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=1> (referer: None)
# 2020-03-16 01:41:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2> (referer: None)
# 2020-03-16 01:41:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3> (referer: None)
# 2020-03-16 01:41:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5> (referer: None)
# 2020-03-16 01:41:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16978> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16980> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16968> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16646> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16978>
# {'desc': '발효차 삼다연 베이스의 오리지널 밀크티입니다. 분말 형태로 되어있어 간편하게 즐기실 수 있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/FA/YT/20191216160219867FY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16978',
#  'price': '12,000',
#  'star': '4.7',
#  'title': '삼다연오리지널밀크티 10입'}
# 2020-03-16 01:41:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16348> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=4)
# 2020-03-16 01:41:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/5764> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16980>
# {'desc': '녹차의 깊은 풍미를 두배 더한 더블샷 라떼. ',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WM/NB/20191216160850911BY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16980',
#  'price': '12,000',
#  'star': '4.5',
#  'title': '그린티라떼더블샷 10입'}
# 2020-03-16 01:41:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16968>
# {'desc': '달큰한 배향이 달빛처럼 은은하게 감도는 후발효차를 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/SW/LS/20191216151128674DO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16968',
#  'price': '15,000',
#  'star': '4.9',
#  'title': '달빛걷기 10입(피라미드)'}
# 2020-03-16 01:41:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16646>
# {'desc': '깨끗한 제주의 신선한 찻잎을 정성스레 덖은 녹차입니다. 부담없는 가격으로 오설록의 녹차를 즐길 수 있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/NS/QP/20191007152144573YX.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16646',
#  'price': '13,500',
#  'star': '4.7',
#  'title': '덖음차 50 g(잎차)'}
# 2020-03-16 01:41:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16348>
# {'desc': '은은하고 달콤한 향의 순한 화차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/IC/NH/20191014194452287BC.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16348',
#  'price': '25,000',
#  'star': '4.6',
#  'title': '캐모마일 18g(잎차)'}
# 2020-03-16 01:41:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/5764>
# {'desc': '차 향기와 함께, 비밀스러운 세계 여행 이야기가 펼쳐지는 티 모음 세트입니다. 9가지의 차를 다양하게 즐길 수 있는 '
#          '세트입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WG/AK/20170525143048972GN.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/5764',
#  'price': '45,000',
#  'star': '4.8',
#  'title': '시크릿티스토리'}
# 2020-03-16 01:41:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/14123> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17003> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16359> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/6187> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/14123>
# {'desc': '마스터의 블렌딩으로 탄생한 오설록만의 제주의 향기를 담은 대표 블렌디드 티 모음 세트 입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/RB/SP/20170418183503104KB.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/14123',
#  'price': '50,000',
#  'star': '4.7',
#  'title': '마스터블렌드'}
# 2020-03-16 01:41:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16344> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/4526> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17003>
# {'desc': '어린 찻잎을 정성껏 갈아 만든 깊은 풍미의 유기농 말차\r\n\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/ZP/EV/20191217181023859TD.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17003',
#  'price': '23,000',
#  'star': '4.8',
#  'title': '프리미엄 말차 40g'}
# 2020-03-16 01:41:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16359>
# {'desc': '제주 차밭의 어린 찻잎으로 만든 작설차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/DA/ZO/20190919204622803GY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16359',
#  'price': '36,000',
#  'star': '4.8',
#  'title': '세작 80g(잎차)'}
# 2020-03-16 01:41:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/6187>
# {'desc': '에메랄드빛 제주 바다를 닮은 머스캣향 아이스티입니다. 찬물에도 잘 우러나와 간편하게 즐기실 수 있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/IN/XS/20180716000103719MT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/6187',
#  'price': '12,000',
#  'star': '4.6',
#  'title': '산호섬 20입(아이스티)'}
# 2020-03-16 01:41:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/1461> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16344>
# {'desc': '깊어가는 그윽한 가을향을 품은 국화차 입니다.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/AB/YR/20191014204836186EW.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16344',
#  'price': '40,000',
#  'star': '4.8',
#  'title': '국화차 40g(잎차)'}
# 2020-03-16 01:41:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/4526>
# {'desc': '제주 꽃길에서 느꼈던 설렘의 향기와 달콤했던 사랑의 추억을 떠 올려줄 제주 꽃을 모티브로 한 BEST TEA SET '
#          '입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WI/QY/20181231210610634HR.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/4526',
#  'price': '38,000',
#  'star': '4.8',
#  'title': '메모리인제주세트 20입'}
# 2020-03-16 01:41:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/1461>
# {'desc': '즐겁고 행복한 티타임을 선사하는 달콤하고 향긋한 오설록만의 특별한 블렌디드 티 선물세트 입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/PM/FK/20180510132548266RY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/1461',
#  'price': '20,000',
#  'star': '4.6',
#  'title': '러블리티박스'}
# 2020-03-16 01:41:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15263> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/2402> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/13683> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15263>
# {'desc': '즐거운 티타임을 위해 다양한 맛과 향을 담은 프리미엄 티백 세트',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/BK/ZR/20180904143404408UV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15263',
#  'price': '25,000',
#  'star': '4.7',
#  'title': '프리미엄 티컬렉션'}
# 2020-03-16 01:41:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16983> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17066> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=0)
# 2020-03-16 01:41:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16184> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16147> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16183> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/2402>
# {'desc': '해당 제품은 리뉴얼되었습니다. 새로운 모습을 만나보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/LA/XG/20160829144216942IB.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/2402',
#  'price': '15,000',
#  'star': '0.0',
#  'title': '바람노래 10입(하드케이스)'}
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/13683>
# {'desc': '해당 제품은 단종되었습니다. 더 좋은 제품으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/FR/EE/20181107145720469AD.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/13683',
#  'price': '15,000',
#  'star': '4.6',
#  'title': '삼다연국화 10입(하드케이스)'}
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16983>
# {'desc': '제주 오설록 직영 차밭에서 100% 유기농으로 재배한 프리미엄 가루 녹차입니다. 어디에나 간편하게 톡톡 뿌려 즐기실 수 '
#          '있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/HJ/HP/20191217102813480PT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16983',
#  'price': '10,000',
#  'star': '4.5',
#  'title': '가루녹차 40g'}
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17066>
# {'desc': ' 제주 동백꽃향과 열대과일의 달콤한 풍미가 매력적인 블렌디드티   \r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/SW/RN/20200103141443564RH.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17066',
#  'price': '20,700',
#  'star': '4.9',
#  'title': '동백이피는곶자왈 20입(피라미드)'}
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16184>
# {'desc': '해당 제품은 리뉴얼 예정입니다. 새로운 모습으로 찾아뵙겠습니다.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TW/VS/20190705173554573TV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16184',
#  'price': '22,500',
#  'star': '0.0',
#  'title': '달빛보틀 + WATER+ 레몬라임 30입(분말)'}
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16147>
# {'desc': '해당 제품은 리뉴얼 예정입니다. 새로운 모습으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/BZ/UK/20190626172515933VZ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16147',
#  'price': '36,000',
#  'star': '0.0',
#  'title': '워터플러스 레몬라임30입*2ea'}
# 2020-03-16 01:41:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16192> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16190> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16183>
# {'desc': '해당 제품은 리뉴얼 예정입니다. 새로운 모습으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/IC/NJ/20190705173534077WG.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16183',
#  'price': '22,500',
#  'star': '0.0',
#  'title': '달빛보틀 + WATER+ 핑크사워 30입(분말)'}
# 2020-03-16 01:41:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16185> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16192>
# {'desc': '깔끔하고 휴대성이 좋은 오설록 텀블러와 함께 제주 햇살 받고 자란 싱그러운 제주 영귤 아이스티를 시원하게 즐기세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/SS/NW/20190705173735416TR.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16192',
#  'price': '20,000',
#  'star': '0.0',
#  'title': 'ice텀블러 + 영귤섬 20입(아이스티)'}
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16190>
# {'desc': '휴대성이 좋은 달빛걷기 이미지의 오설록 보틀과 함께 언제 어디서나 쉽고 간편하게 시원한 녹차를 즐기세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GK/QM/20190705173649403RS.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16190',
#  'price': '12,000',
#  'star': '0.0',
#  'title': '달빛보틀 + 찬물녹차 20입(아이스티)'}
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16185>
# {'desc': '해당 제품은 리뉴얼 예정입니다. 새로운 모습으로 찾아뵙겠습니다.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/OC/VG/20190705173816444SC.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16185',
#  'price': '22,500',
#  'star': '0.0',
#  'title': '달빛보틀 + WATER+ 해피스윗 30입(분말)'}
# 2020-03-16 01:41:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16194> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16193> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17143> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17144> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16194>
# {'desc': '깔끔하고 휴대성이 좋은 오설록 텀블러와 함께 언제 어디서나 쉽고 간편하게 시원한 녹차를 즐기세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WJ/RB/20190705173757958MM.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16194',
#  'price': '15,500',
#  'star': '0.0',
#  'title': 'ice텀블러 + 찬물녹차 20입(아이스티)'}
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16193>
# {'desc': '깔끔하고 휴대성이 좋은 오설록 텀블러와 함께 제주 여름밤의 시원함을 담은 배향 아이스티를 시원하게 즐기세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/QH/FH/20190705173747382OO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16193',
#  'price': '20,000',
#  'star': '0.0',
#  'title': 'ice텀블러 + 달빛섬 20입(아이스티)'}
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17143>
# {'desc': '붉은 태양을 닮은 깊은 풍미의순수 루이보스차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/JP/RC/20200131110657210DO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17143',
#  'price': '15,000',
#  'star': '0.0',
#  'title': '루이보스 퓨어 10입(피라미드)'}
# 2020-03-16 01:41:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17144>
# {'desc': '달콤하게 즐기는 블렌디드 루이보스차',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GI/MA/20200131110741168FM.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17144',
#  'price': '15,000',
#  'star': '0.0',
#  'title': '루이보스 카라멜베리 10입(피라미드)'}
# 2020-03-16 01:41:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16227> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16227>
# {'desc': '휴대성이 좋은 달빛걷기 이미지의 오설록 보틀과 함께 국내산 국화의 진한향을 즐기세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/BI/UO/20200213095130432MQ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16227',
#  'price': '19,500',
#  'star': '0.0',
#  'title': '굿나잇 허브차 보틀 세트'}
# 2020-03-16 01:41:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16706> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16188> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16191> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16708> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16707> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16350> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16706>
# {'desc': '가장 먼저 딴 여린 차순을 정성스레 덖어낸 오설록 고급 우전차입니다. 피라미드 티백으로 간편하게 고급스러운 티타임을 '
#          '즐기세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/YA/QS/20200211145740694FA.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16706',
#  'price': '25,000',
#  'star': '2.5',
#  'title': '우전 10입(피라미드)'}
# 2020-03-16 01:41:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16188>
# {'desc': '휴대성이 좋은 달빛걷기 이미지의 오설록 보틀과 함께 제주 햇살 받고 자란 싱그러운 제주 영귤 아이스티를 시원하게 '
#          '즐기세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/HV/IE/20200227103515964NP.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16188',
#  'price': '8,250',
#  'star': '5.0',
#  'title': '달빛보틀 + 영귤섬 20입(아이스티)'}
# 2020-03-16 01:41:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16191>
# {'desc': '깔끔하고 휴대성이 좋은 오설록 텀블러와 함께 에메랄드빛 제주 바다를 닮은 머스캣향 아이스티를 시원하게 즐기세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/FK/QT/20190705173722555GF.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16191',
#  'price': '20,000',
#  'star': '5.0',
#  'title': 'ice텀블러 + 산호섬 20입(아이스티)'}
# 2020-03-16 01:41:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16708>
# {'desc': '붉은 노을을 닮은 붉고 진한 수색과 풍부한 향기를 가진 강발효차를 피라미드 티백으로 간편하게 고급스러운 티타임을 즐기세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/KQ/KG/20200211145812768YA.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16708',
#  'price': '30,000',
#  'star': '5.0',
#  'title': '홍우전 10입(피라미드)'}
# 2020-03-16 01:41:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16707>
# {'desc': '이른 아침부터 늦은 저녁까지 계속 발효하여, 붉은 노을을 닮은 붉고 진한 수색과 풍부한 향기를 즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/DC/IJ/20200211145828710PJ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16707',
#  'price': '90,000',
#  'star': '5.0',
#  'title': '홍우전 60 g(잎차)'}
# 2020-03-16 01:41:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16350>
# {'desc': '기분좋은 상쾌함을 선사하는 허브차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/HJ/UD/20190919203145281QH.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16350',
#  'price': '12,000',
#  'star': '4.0',
#  'title': '모로칸민트티 10입(피라미드)'}
# 2020-03-16 01:41:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16145> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16045> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16784> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16145>
# {'desc': '해당 제품은 리뉴얼 예정입니다. 새로운 모습으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/QS/DB/20190626171849736AW.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16145',
#  'price': '36,000',
#  'star': '5.0',
#  'title': '워터플러스 해피스윗30입*2ea'}
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16045>
# {'desc': '품격있는 선물을 위한 프리미엄 세트',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TV/PK/20190508090626831SV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16045',
#  'price': '70,000',
#  'star': '5.0',
#  'title': '프리미엄 티 컬렉션 90입(티백)'}
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16353> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16362> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16784>
# {'desc': '오설록의 월출산 차밭에서 이른 봄 돋아난 첫 새싹만 정성껏 발효하고 덖었습니다. 월출산 자락의 향미를 즐겨보세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/PH/RO/20191105143548781NO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16784',
#  'price': '90,000',
#  'star': '4.5',
#  'title': '월출향 60 g(잎차)'}
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16148> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16353>
# {'desc': '한라산의 화산암석층이 키워낸 구수한 풍미의 반발효차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GG/VX/20190919203609252BV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16353',
#  'price': '35,000',
#  'star': '4.8',
#  'title': '제주화산암차 50g(잎차)'}
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16362>
# {'desc': '조화로운 풍미와 오설록 역사를 간직한 녹차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/EP/SJ/20190919204835704PK.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16362',
#  'price': '15,000',
#  'star': '4.8',
#  'title': '억수진 10입(피라미드)'}
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16148>
# {'desc': '해당 제품은 리뉴얼 예정입니다. 새로운 모습으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/UH/OA/20190626172639258VP.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16148',
#  'price': '36,000',
#  'star': '4.8',
#  'title': '워터플러스 핑크사워30입*2ea'}
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16703> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16349> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=5)
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16356> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/17067> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16703>
# {'desc': '가을이 깊어가는 시기에 피어난 향이 진한 국내산 국화로 만든 화차를 피라미드 티백으로 간편하게, 합리적인 가격으로 '
#          '즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/VH/MD/20191017180111961AR.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16703',
#  'price': '23,000',
#  'star': '4.9',
#  'title': '국화차 20입(피라미드)'}
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16349>
# {'desc': '기분좋은 상쾌함을 선사하는 허브차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/XM/BL/20191014204308564QF.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16349',
#  'price': '20,000',
#  'star': '4.5',
#  'title': '모로칸민트티 16g(잎차)'}
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16356>
# {'desc': '제주 삼나무로 오랜 시간 숙성시킨 깊고 부드러운 후발효차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GV/HN/20190919204230223ZD.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16356',
#  'price': '15,000',
#  'star': '4.6',
#  'title': '삼다연 10입(피라미드)'}
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/17067>
# {'desc': ' 제주 동백꽃향과 열대과일의 달콤한 풍미가 매력적인 블렌디드티   \r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WJ/EU/20200103141807649ZL.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/17067',
#  'price': '13,500',
#  'star': '4.6',
#  'title': '동백이피는곶자왈 35g(잎차)'}
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16948> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15586> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16948>
# {'desc': '1년에 단 10일만을 꽃 피우는 제주한란의 청아한 향을 담은 오리엔탈 그린티를 원하는 용량만큼 우려드실 수 있는 '
#          '잎차입니다. 합리적인 가격에 즐겨보세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/IT/HN/20191213163103992SW.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16948',
#  'price': '15,000',
#  'star': '4.5',
#  'title': '제주난꽃향그린티 35 g(잎차)'}
# 2020-03-16 01:41:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15586>
# {'desc': '산뜻한 제주 얼그레이와 고소한 풍미가 가득한 가을밤 블렌디드 티입니다. 달콤고소한 알밤의 맛과 향을 좋아하시는 분께 '
#          '추천합니다.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/DO/OZ/20181203110344421KT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15586',
#  'price': '15,000',
#  'star': '4.8',
#  'title': '느랏느랏 가을 밤 10입'}
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16783> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16263> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16704> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15133> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16783>
# {'desc': '어린 차싹의 형상을 그대로 간직한 오설록의 최고 명차입니다. 중요한 분께 가치있는 선물로 추천합니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/ET/KA/20200224163154862PM.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16783',
#  'price': '170,000',
#  'star': '4.9',
#  'title': '일로향 60 g(잎차)'}
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16263>
# {'desc': '[온라인몰 한정판매]중후하고 구수한 반발효차',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/AN/SQ/20190808150625126WD.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16263',
#  'price': '8,500',
#  'star': '4.4',
#  'title': '제주 한라발효차 20EA(티백)'}
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16704>
# {'desc': '예로부터 환절기에 차로 만들어 마시곤 했던 도라지차를 피라미드 티백으로 간편하게, 합리적인 가격으로 즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WN/NQ/20191017180359157FJ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16704',
#  'price': '23,000',
#  'star': '4.8',
#  'title': '도라지차 20입(피라미드)'}
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15133>
# {'desc': '깊은 땅속의 영양을 가득 담은 뿌리 채소인 우엉차를 고급스러운 지함에 담았습니다. 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/QY/BV/20180405134702712YG.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15133',
#  'price': '12,000',
#  'star': '4.8',
#  'title': '우엉차 10입(하드케이스)'}
# 2020-03-16 01:41:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16043> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15624> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16043>
# {'desc': '[온라인 전용 세트] Thank you ',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/UU/XR/20190416161931537QN.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16043',
#  'price': '22,000',
#  'star': '4.3',
#  'title': '오땡큐 티박스 6종'}
# 2020-03-16 01:41:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16964> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/3602> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15624>
# {'desc': '상쾌한 향기와 청량감을 주는 페퍼민트와 삶의 활력을 더해주는 로즈힙 블렌디드 티로 답답했던 기분을 개운하게 씻어내 보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GJ/DB/20181005092203810SQ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15624',
#  'price': '15,000',
#  'star': '4.5',
#  'title': '포레스트 브레스 10입(하드케이스)'}
# 2020-03-16 01:41:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16355> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16645> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16964>
# {'desc': '한라산의 화산암석층이 키워낸 구수한 풍미의 반발효차',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/YN/YX/20191216144903751AZ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16964',
#  'price': '4,500',
#  'star': '4.5',
#  'title': '제주화산암차 3입 DIY(피라미드)'}
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/3602>
# {'desc': '제주 꽃길에서 느꼈던 설렘의 향기와 달콤했던 사랑의 추억을 떠 올려줄 제주 꽃을 모티브로 한 티 4종 세트입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GC/CM/20170925093746639SL.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/3602',
#  'price': '68,000',
#  'star': '4.4',
#  'title': '메모리인제주세트 40입'}
# 2020-03-16 01:41:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/14683> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/14884> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16355>
# {'desc': '제주 삼나무로 오랜 시간 숙성시킨 깊고 부드러운 후발효차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/NN/KX/20190919204108371FV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16355',
#  'price': '40,000',
#  'star': '4.5',
#  'title': '삼다연 80g(잎차)'}
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16645>
# {'desc': '한라산의 화산암석층이 키워낸 구수한 풍미의 반발효차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/KL/QJ/20191007151821447QU.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16645',
#  'price': '23,000',
#  'star': '4.9',
#  'title': '제주화산암차 20입(피라미드)'}
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/14683>
# {'desc': '해당 제품은 단종되었습니다. 더 좋은 제품으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/MO/QP/20180716152412553UF.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/14683',
#  'price': '35,000',
#  'star': '4.4',
#  'title': '디저티세트'}
# 2020-03-16 01:41:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/14884>
# {'desc': '어린 녹차로 만든 명차수와 녹차 복합 성분이 함유되어 피부결을 매끄럽고 촉촉하게 가꿔주는 핸드크림입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/VU/NH/20171215113619286ZN.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/14884',
#  'price': '15,000',
#  'star': '4.6',
#  'title': '그린티 핸드크림 3종'}
# 2020-03-16 01:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16977> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15583> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16644> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16977>
# {'desc': '열대과일향의 달콤함에 금빛 노을처럼 물든 티를 소중한 사람에게 선물해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TF/VT/20191216155932976KH.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16977',
#  'price': '15,000',
#  'star': '4.6',
#  'title': '금빛마중 10입(피라미드)'}
# 2020-03-16 01:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16361> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-03-16 01:41:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15583>
# {'desc': '크림같은 부드러움과 상큼한 과즙이 가득한 산딸기 블렌디드 티입니다. 싱그러운 베리의 맛과 향을 좋아하시는분께 추천합니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/KV/LI/20181203110302921DI.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15583',
#  'price': '15,000',
#  'star': '4.7',
#  'title': '산도롱 산딸기 10입'}
# 2020-03-16 01:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/14163> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=3)
# 2020-03-16 01:41:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16644>
# {'desc': '한라산의 화산암석층이 키워낸 구수한 풍미의 반발효차',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/LU/OP/20191007151511229GH.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16644',
#  'price': '15,000',
#  'star': '4.9',
#  'title': '제주화산암차 30 g(잎차)'}
# 2020-03-16 01:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/14384> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-03-16 01:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15244> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-03-16 01:41:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16361>
# {'desc': '조화로운 풍미와 오설록 역사를 간직한 녹차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/RW/XZ/20191014194139623UA.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16361',
#  'price': '30,000',
#  'star': '4.8',
#  'title': '억수진 80g(잎차)'}
# 2020-03-16 01:41:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/14163>
# {'desc': '차 한잔의 습관은 삶의 아름다움을 더합니다. 아름다워지는 생활습관을 가져다주는 석류&히비스커스 블렌디드 티로 뷰티풀한 '
#          '라이프를 즐겨보세요',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/GK/RR/20190225163902588CQ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/14163',
#  'price': '15,000',
#  'star': '4.9',
#  'title': '뷰티풀라이프 10입(하드케이스)'}
# 2020-03-16 01:41:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/14384>
# {'desc': '해당 제품은 리뉴얼 예정입니다. 새로운 모습으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/VS/MN/20180724134811601DT.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/14384',
#  'price': '18,000',
#  'star': '4.8',
#  'title': 'WATER+ 레몬라임 30입(분말)'}
# 2020-03-16 01:41:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15244>
# {'desc': '제주산 홍차와 열대과일의 새콤달콤한 풍미로 기분까지 좋아지는 블렌디드 티입니다.  제주 차밭의 맛과 향을 가벼운 가격으로 '
#          '즐겨보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WB/DP/20180906153620161PJ.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15244',
#  'price': '8,500',
#  'star': '4.7',
#  'title': '트로피컬블랙티 20입(티백)'}
# 2020-03-16 01:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15623> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-03-16 01:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16763> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-03-16 01:41:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15623>
# {'desc': '편안한 밤을 위한 특별한 향취를 가진 발레리안과 향기로운 향으로 몸을 감싸주는 라벤더 블렌디드 티로 행복한 꿈을 '
#          '꾸어보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/LN/XT/20181201000503014TV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15623',
#  'price': '15,000',
#  'star': '4.4',
#  'title': '미드나잇 슬립 10입(하드케이스)'}
# 2020-03-16 01:41:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16763>
# {'desc': '제주 삼나무의 그윽한 풍미에 제주영귤의 싱그러움을 더한 후발효차를 처음 접하시거나 다양한 차를 조금씩 맛보고 싶으시다면, '
#          '3입 제품으로 합리적인 가격에 체험해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/QC/WI/20191101134237848CE.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16763',
#  'price': '4,500',
#  'star': '4.7',
#  'title': '삼다연제주영귤 3입(DIY)'}
# 2020-03-16 01:41:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/14383> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-03-16 01:41:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16971> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-03-16 01:41:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16357> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-03-16 01:41:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/14383>
# {'desc': '해당 제품은 리뉴얼 예정입니다. 새로운 모습으로 찾아뵙겠습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/PD/PS/20180724134803233CK.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/14383',
#  'price': '18,000',
#  'star': '4.6',
#  'title': 'WATER+ 해피스윗 30입(분말)'}
# 2020-03-16 01:41:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16976> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-03-16 01:41:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16971>
# {'desc': '제주 동백꽃향과 열대과일의 달콤한 풍미가 매력적인 블렌디드티를 처음 접하시거나 다양한 차를 조금씩 맛보고 싶으시다면, 3입 '
#          '제품으로 합리적인 가격에 체험해보세요.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/CF/DQ/20191216152751258TP.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16971',
#  'price': '4,500',
#  'star': '4.7',
#  'title': '동백이피는곶자왈 3입(피라미드)'}
# 2020-03-16 01:41:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16360> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=teashop&p=2)
# 2020-03-16 01:41:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16357>
# {'desc': '제주 숲 차밭의 어린 찻잎으로 만든 산뜻한 향미의 홍차\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/LB/AG/20190919204435687HR.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16357',
#  'price': '40,000',
#  'star': '4.8',
#  'title': '제주숲홍차 80g(잎차)'}
# ...
# 2020-03-16 01:42:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/16044> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=2)
# 2020-03-16 01:42:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/17405>
# {'desc': '좋아하는 제품 2가지를 마음대로 골라 담으세요.\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/KI/IJ/20200302145646395CO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/17405',
#  'price': '3,000',
#  'star': '4.7',
#  'title': '2입 세트 포장 박스 (10입제품용)'}
# 2020-03-16 01:42:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/15144> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=2)
# 2020-03-16 01:42:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/15023> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/13943> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=2)
# 2020-03-16 01:42:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/16044>
# {'desc': '[온라인 전용 세트]제주숲 동화',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/LA/VF/20190416162326756NH.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/16044',
#  'price': '25,000',
#  'star': '4.4',
#  'title': '제주숲 동화 3종 미니 세트'}
# 2020-03-16 01:42:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/15144>
# {'desc': '제주만의 특별함을 담아내어 블렌딩한 프리미엄 티백 라인입니다. 그 중에서도 달달한 맛과 향을 가진 제품을 3가지 모은 '
#          '세트입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/RH/LB/20180403121530820RY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/15144',
#  'price': '27,500',
#  'star': '4.7',
#  'title': '달달 박스'}
# 2020-03-16 01:42:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/15023>
# {'desc': '진한 녹차의 풍미를 느낄 수 있는 프리미엄 랑 드 샤',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/IB/KE/20200219170427376HM.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/15023',
#  'price': '36,000',
#  'star': '4.7',
#  'title': '그린티 랑드샤 300g(3box)'}
# 2020-03-16 01:42:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/13943>
# {'desc': '고급감이 느껴지는 우드 케이스로 품격있는 선물로 최적의 가치를 드리는 오설록의 명차세트 입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/FA/MG/20180716152531661KO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/13943',
#  'price': '120,000',
#  'star': '4.9',
#  'title': '프리미엄 티 기프트 세트'}
# 2020-03-16 01:42:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/14766> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/14764> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/14372> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/14766>
# {'desc': 'office공간에서, 업무 중에 언제든 오설록 티하우스에 있는 것 처럼~ 차 한잔으로 업무로 지친 당신에게 여유를 '
#          '선물하세요!',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TN/EF/20181022092927413FO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/14766',
#  'price': '8,500',
#  'star': '4.9',
#  'title': '오피스Tea(순수녹차)'}
# 2020-03-16 01:42:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/6244> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/14764>
# {'desc': 'office공간에서, 업무 중에 언제든 오설록 티하우스에 있는 것 처럼~ 차 한잔으로 업무로 지친 당신에게 여유를 '
#          '선물하세요!',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/RW/AN/20181022092959484EK.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/14764',
#  'price': '8,500',
#  'star': '4.7',
#  'title': '오피스Tea(유채&꿀)'}
# 2020-03-16 01:42:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/14372>
# {'desc': '어린 녹차로 만든 명차수와 천연 유래 코코넛 오일이 함유된 프리미엄 클렌징 바입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/FM/SL/20180906141602487RA.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/14372',
#  'price': '10,000',
#  'star': '4.7',
#  'title': '그린티 클렌징바'}
# 2020-03-16 01:42:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/6244>
# {'desc': '머스캣향 아이스티와 시원함을 담은 배향 아이스티입니다. 찬물에도 잘 우러나와 간편하게 즐기실 수 있습니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/KX/VJ/20180731143814733FD.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/6244',
#  'price': '24,000',
#  'star': '4.8',
#  'title': '파라다이스 세트'}
# 2020-03-16 01:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/bakery/16363> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/14765> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/14023> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/6242> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15524> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/2684> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/bakery/16363>
# {'desc': '진한 녹차 크림의 풍미를 느낄 수 있는 프리미엄 웨하스\r\n',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/QT/IG/20190919205017968RP.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/bakery/16363',
#  'price': '5,000',
#  'star': '4.7',
#  'title': '그린티웨하스 100g'}
# 2020-03-16 01:42:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/14765>
# {'desc': 'office공간에서, 업무 중에 언제든 오설록 티하우스에 있는 것 처럼~ 차 한잔으로 업무로 지친 당신에게 여유를 '
#          '선물하세요!',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/ZI/PC/20181022092946979JU.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/14765',
#  'price': '8,500',
#  'star': '4.8',
#  'title': '오피스Tea(동백꽃)'}
# 2020-03-16 01:42:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/14023>
# {'desc': '아기자기 오브제가 달려있고 플로팅 방식의 티 인퓨저입니다. 찻 잔에 띄워놓고 떠 있는 모습을 바라보면 기분마저 좋아집니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/NB/LQ/20170206143530155AD.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/14023',
#  'price': '13,000',
#  'star': '4.5',
#  'title': '티 인퓨저(아기자기)'}
# 2020-03-16 01:42:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/6242>
# {'desc': '어느 머그에나 사용할 수 있는, 편리하고 실용적인 티 스트레이너입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/ZH/KI/20160829162434422NR.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/6242',
#  'price': '10,000',
#  'star': '4.6',
#  'title': '오설록 티 스트레이너'}
# 2020-03-16 01:42:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15524>
# {'desc': '제주 숲 동화 4종으로 구성된 기프트 세트',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/SM/OU/20180904173031662SD.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15524',
#  'price': '35,000',
#  'star': '4.6',
#  'title': '제주숲 동화 4종 세트'}
# 2020-03-16 01:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/15083> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/14763> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/2684>
# {'desc': '향긋한 차의 세계를 경험할 수 있는 오설록의 블렌디드 티 베스트 3종을 모아 둔 티 컬렉션입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/BP/LG/20171110104835223PV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/2684',
#  'price': '47,000',
#  'star': '4.9',
#  'title': '베스트티컬렉션 3종'}
# 2020-03-16 01:42:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/15083>
# {'desc': '녹차, 호지차 스프레드와 별도 포장이 필요 없는 고급 패키지로 구성된 쨈 2종 세트입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/SO/QD/20190704100911630UX.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/15083',
#  'price': '19,000',
#  'star': '4.5',
#  'title': '오설록의 고급 녹차쨈 세트'}
# 2020-03-16 01:42:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/14763>
# {'desc': 'office공간에서, 업무 중에 언제든 오설록 티하우스에 있는 것 처럼~ 차 한잔으로 업무로 지친 당신에게 여유를 '
#          '선물하세요!',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TL/UJ/20181022092936967DV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/14763',
#  'price': '8,500',
#  'star': '4.8',
#  'title': '오피스Tea(삼다영귤)'}
# 2020-03-16 01:42:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/5701> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/5701>
# {'desc': '귀여운 오브제가 멋을 더해주는, 어떤 컵에도 차를 우릴 수 있는 팬시한 티 인퓨저입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TX/AE/20181217111236368TO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/5701',
#  'price': '13,000',
#  'star': '4.5',
#  'title': '티 인퓨저'}
# 2020-03-16 01:42:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/5764> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/themashop/113> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/6044> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/5764>
# {'desc': '차 향기와 함께, 비밀스러운 세계 여행 이야기가 펼쳐지는 티 모음 세트입니다. 9가지의 차를 다양하게 즐길 수 있는 '
#          '세트입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WG/AK/20170525143048972GN.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/5764',
#  'price': '45,000',
#  'star': '4.8',
#  'title': '시크릿티스토리'}
# 2020-03-16 01:42:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/15263> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/14123> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.osulloc.com/kr/ko/shop/item/teashop/4526> (referer: https://www.osulloc.com/kr/ko/shop/item/list?category=themashop&p=0)
# 2020-03-16 01:42:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/themashop/113>
# {'desc': '거름망이 있어 간편하게 잎차를 우려마실 수 있는 팬시한 오설록 그린컵',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/TT/ND/20160910154959317DO.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/themashop/113',
#  'price': '9,000',
#  'star': '4.7',
#  'title': '그린컵 225ml(아이보리)'}
# 2020-03-16 01:42:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/6044>
# {'desc': '제주의 아름다운 숨은 비경을 담은 블렌디드 티 모음 세트 입니다. 다양한 블렌디드 티를 좋아하시는 분께 선물하시기 좋은 '
#          '제품입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/XI/NH/20160908175048786BY.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/6044',
#  'price': '27,000',
#  'star': '4.7',
#  'title': '신오브제주세트'}
# 2020-03-16 01:42:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/15263>
# {'desc': '즐거운 티타임을 위해 다양한 맛과 향을 담은 프리미엄 티백 세트',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/BK/ZR/20180904143404408UV.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/15263',
#  'price': '25,000',
#  'star': '4.7',
#  'title': '프리미엄 티컬렉션'}
# 2020-03-16 01:42:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/14123>
# {'desc': '마스터의 블렌딩으로 탄생한 오설록만의 제주의 향기를 담은 대표 블렌디드 티 모음 세트 입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/RB/SP/20170418183503104KB.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/14123',
#  'price': '50,000',
#  'star': '4.7',
#  'title': '마스터블렌드'}
# 2020-03-16 01:42:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.osulloc.com/kr/ko/shop/item/teashop/4526>
# {'desc': '제주 꽃길에서 느꼈던 설렘의 향기와 달콤했던 사랑의 추억을 떠 올려줄 제주 꽃을 모티브로 한 BEST TEA SET '
#          '입니다.',
#  'img': 'https://www.osulloc.com/upload/kr/ko/adminImage/WI/QY/20181231210610634HR.png?quality=80',
#  'link': 'https://www.osulloc.com/kr/ko/shop/item/teashop/4526',
#  'price': '38,000',
#  'star': '4.8',
#  'title': '메모리인제주세트 20입'}
# 2020-03-16 01:42:16 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-03-16 01:42:16 [scrapy.extensions.feedexport] INFO: Stored csv feed (83 items) in: osulloc_themashop.csv
# 2020-03-16 01:42:16 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 34748,
#  'downloader/request_count': 89,
#  'downloader/request_method_count/GET': 89,
#  'downloader/response_bytes': 4872619,
#  'downloader/response_count': 89,
#  'downloader/response_status_count/200': 89,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 3, 15, 16, 42, 16, 540339),
#  'item_scraped_count': 83,
#  'log_count/DEBUG': 174,
#  'log_count/INFO': 10,
#  'memusage/max': 58982400,
#  'memusage/startup': 58978304,
#  'request_depth_max': 1,
#  'response_received_count': 89,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 88,
#  'scheduler/dequeued/memory': 88,
#  'scheduler/enqueued': 88,
#  'scheduler/enqueued/memory': 88,
#  'start_time': datetime.datetime(2020, 3, 15, 16, 42, 6, 171227)}
# 2020-03-16 01:42:16 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# 크롤링 결과 확인

# %%
df = pd.read_csv("osulloc/osulloc_teashop.csv")

# %%
df.tail(2)
# Out:
#             title                                               desc   price  \
# 239  메모리인제주세트 20입  제주 꽃길에서 느꼈던 설렘의 향기와 달콤했던 사랑의 추억을 떠 올려줄 제주 꽃을 모...  38,000
#
#      star                                                img  \
# 239   4.8  https://www.osulloc.com/upload/kr/ko/adminImag...
#
#                                                   link
# 239  https://www.osulloc.com/kr/ko/shop/item/teasho...

# %%
# 데이터 베이스 저장 확인

# %%
import pymongo

client = pymongo.MongoClient('mongodb://54.180.179.245:27017/')
db = client.osulloc
collection = db.items

# %%
datas = collection.find({}, {"_id": False})

# %%
pd.DataFrame(datas).head(2)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
